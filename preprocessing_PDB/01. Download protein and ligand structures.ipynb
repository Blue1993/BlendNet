# %%
import os
import numpy as np
import pandas as pd
from biopandas.mol2 import PandasMol2
from multiprocessing import Process, Queue, Pool
from rdkit.Chem.rdmolfiles import MolFromSmiles, MolToSmiles

# %% [markdown]
# ### 1. Load SMILES info

# %%
def read_file(file):
    return file.readlines()

def preprocessing_PDB_ligand(lines, sup_dict):

    results = dict()
    
    for line in lines:
        line_list = line.split("\t")
        
        if line_list[1] in sup_dict:
            results[line_list[1]] = sup_dict[line_list[1]]
            
        elif line_list[0] == "":
            continue
        
        else:
            results[line_list[1]] = line_list[0]

    return results

# %%
SMILES_stereo_correct = {"0IU":"C[C@@H](C1=CC=CC=C1)N(CC(=O)N(C)C)C(=O)C[C@@H](CC2=CSC(=N2)N)C(=O)N[C@@H](CC3CCCCC3)[C@H]([C@H](CC(C)C)O)O", 
                     "0QN":"C[C@@H](C(=O)NC1=CC=C(C=C1)C(F)(F)F)NC(=O)[C@H](C(C)C)NC(=O)C(F)(F)F", 
                     "2Z3":"CCCC[C@@H](C(=O)N[C@@H](CC1CCCCC1)C(C(C(=O)NC)(F)F)(O)O)NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)N3CCOCC3", 
                     "0DB":"C1CCC(C1)(C[C@@H](CCC2=CC=CC=C2)C(=O)O)C(=O)N[C@@H](CC3=CNC4=CC=CC=C43)C(=O)O", 
                     "0EM":"CC[C@H](C)CNC(=O)CP(=O)([C@H](CC(C)C)NC(=O)[C@H](CC1=CN=CN1)NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)OC(C)(C)C)O", 
                     "0DY":"CC(C)C[C@@H](C(=O)N[C@@H](CC(=O)N)C(=O)NCC1=CC(=CC=C1)N)C(=O)NO", 
                     "0QB":"C[C@@H](C1=CC=CC=C1)N(CC(=O)N(C)C)C(=O)C[C@@H](CC2=CSC(=N2)N)C(=O)N[C@@H](CC3CCCCC3)[C@H]([C@@H]4CC(N(C4=O)C)(C)C)O", 
                     "0ED":"CC(C)C[C@@H](C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCCN2CCOCC2)N[C@H](CCNC(=O)OCC3=CC=CC=C3)C(=O)O", 
                     "0QH":"CC(C)C[C@@H](C(=O)N[N@+](C)(CC1=CC=CC=C1)CC(=O)NC2=CC=C(C=C2)C(C)C)NC(=O)C(F)(F)F", 
                     "0Z0":"C[C@@H](C(=O)NC1=CC=C(C=C1)C(F)(F)F)NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)C(F)(F)F", 
                     "0ZB":"CC(C)C[C@@H](C(=O)N[C@@H](CC(=O)O)C(=O)NCC1=CC=CC=C1)C(=O)NO", 
                     "0D3":"C[C@@H](C(=O)NCC(=O)N)NC(=O)[C@H](CC1=CC=CC=C1)CS", 
                     "0ZC":"CC(C)C[C@@H](C(=O)N1CC2=C(C[C@H]1C(=O)O)C3=CC=CC=C3N2)NC(=O)C4=CC=CO4", 
                     "01S":"C[C@@H](C(=O)NCC(=O)N)NC(=O)[C@H](CC(C)C)C(=O)NO", 
                     "0E9":"CC(C)[C@@H](C(=O)N[C@@H](CC1=CC=CC=C1)C([C@H](CC2=CC=CC=C2)NC(=O)[C@H](C(C)C)NC(=O)OCC3=CC=CC=C3)O)NC(=O)OCC4=CC=CC=C4",
                     "0PK":"C[C@@H](C(=O)O)NC(=O)[C@H](CC(C)C)NP(=O)([C@H](CC1=CC=CC=C1)NC(=O)OCC2=CC=CC=C2)O",
                     "0PJ":"CC(C)C[C@@H](C(=O)N[C@@H](CC(C)C)C(=O)O)NP(=O)(CNC(=O)OCC1=CC=CC=C1)O"
                    }

# %%
# This file is from the Ligand expo database (http://ligand-expo.rcsb.org/ld-download.html).
PDB_ligand_isomeric_dict = preprocessing_PDB_ligand(read_file(open("./data/supplementary/Components-smiles-stereo-oe.smi", "r")), 
                                                  SMILES_stereo_correct)

# %%
print(f"[Ligand Isomeric] SMILES: {len(PDB_ligand_isomeric_dict)}")
# Out:
# [Ligand Isomeric] SMILES: 40464

# %% [markdown]
# ### 2. Preprocessing datasets

# %%
def read_file(file):
    return file.readlines()

def get_ligand_code(line):
    return line.split(" ")[-1].rstrip(")").lstrip("(").strip("_")

def convert(value, unit):
    if unit == 'nM':
        log_value = -np.log10(value)+9
    elif unit == 'uM':
        log_value = -np.log10(value)+6
    elif unit == 'mM':
        log_value = -np.log10(value)+3
    elif unit == 'pM':
        log_value = -np.log10(value)+12
    elif unit == 'fM':
        log_value = -np.log10(value)+15
    else:
        print(unit)    
    
    return str(np.round(log_value,2))

def get_values(line):
    measure, value, unit = line.split('=')[0], line.split('=')[1][:-2], line.split('=')[1][-2:]
    return measure, value, unit, convert(float(value), unit)

# %%
def preprocessing_PDBbind(lines, ligand_stereo_dict, amino_acids_short):
    
    results = dict()

    correct_ligand_code = {"6hzp":"FVT", "6mli":"HIS", "6mmq":"CMP", "6mlp":"HIS", "6nfg":"KKP", 
                           "3adu":"MYI", "6imd":"AH9", "6jad":"GLC", "6jag":"SUC", "1czo":"FMN", 
                           "1d04":"FMN", "6hbm":"AHR", "6agp":"GDP", "6nfo":"KKM", "6hop":"FER", 
                           "1aku":"FMN", "6jki":"SFG", "6a73":"IHP", "6hmb":"3NG", "6mdb":"JE4", 
                           "6mhd":"JRD", "6jz0":"CKO", "6myn":"K6Y", "6ocu":"M5D", "6hub":"GRW", 
                           "5xff":"6LF", "5xfj":"6LF", "1akt":"FMN", "1akw":"FMN", "1azl":"FMN", 
                           "6n3n":"KA4", "1czk":"FMN", "1czr":"FMN", "1akr":"FMN", "1akq":"FMN",
                           "1czl":"FMN", "6moo":"A5F", "1c7f":"FMN", "1akv":"FMN", "1i7m":"CG",
                           "6cqt":"VX", "6cqz":"VX", "1xzx":"T3", "1a5v":"Y3", "1af2":"U", 
                           "1phw":"N", "2gfj":"VI", "1kll":"MC", "6o4x":"AA",
                            "5moq":"BEN", "1tyr":"9CR", "3t83":"MG5", "4elh":"53I", "5w0l":"9UD", 
                            "5mnh":"BEN", "1h00":"FCP", "4p0n":"1IR", "4a50":"DQ6", "5n9n":"KC5", 
                            "5lvx":"7E4", "1p28":"HBS", "1bap":"ARA", "5x72":"P59", "5mo0":"BEN", 
                            "3lk1":"JKE", "6eu6":"ZDM", "2cht":"TSA", "1apb":"FCA", "1oko":"GAL", 
                            "1f5k":"BEN", "7abp":"FCA", "5g6u":"SGN", "5ijj":"IHP", "4q1e":"2Y7", 
                            "5mng":"BEN", "3rv6":"RVA", "5mw3":"5JJ", "5wkm":"N02", "1c5p":"BEN", 
                            "1abf":"FCA", "6qs5":"JGB", "2srt":"8MI", "9abp":"GLA", "4d1d":"5ND", 
                            "4elg":"52I", "1c5o":"BEN", "1h07":"MFP", "3rv8":"RVC", "6eiz":"FOF", 
                            "1c5z":"BEN", "4qhp":"32Q", "5ijp":"IHP", "6abp":"ARA", "5abp":"GLA", 
                            "1ws5":"MMA", "5wkl":"AVY", "8abp":"GLA", "5t52":"A2G", "3uwl":"FFO",
                            "2qtr":"DND", "2x4z":"7KC", "1rdn":"NDG", "1szm":"BI4", "2qwe":"ZMR", 
                            "3dla":"DND", "4elb":"34R"}   
    for line in lines[6:]:
        
        line_list, ligand_code = line.strip().split("//")[0].strip().split('  '), get_ligand_code(line.strip().split("//")[-1].strip())

        if line_list[0] in correct_ligand_code:
            ligand_code = correct_ligand_code[line_list[0]]

        if 'mer' in ligand_code:
            continue

        elif '<' in line_list[4] or '>' in line_list[4] or '~' in line_list[4]:
            continue

        elif ligand_code not in ligand_stereo_dict:
            continue

        elif ligand_code in amino_acids_short:
            continue

        else:
            measure, value, unit, aff = get_values(line_list[4])
            results[line_list[0]] = [measure, value, unit, aff, line_list[3], ligand_code] 

    return results

# %%
amino_acids_short = {"ALA":"A", "ARG":"R", "ASN":"N", "ASP":"D", "CYS":"C", "GLU":"E", "GLN":"Q", "GLY":"G", "HIS":"H", "ILE":"I", "LEU":"L", "LYS":"K", "MET":"M", "PHE":"F", "PRO":"P", "SER":"S", "THR":"T", "TRP":"W", "TYR":"Y", "VAL":"V", "SEC":"U", "PYL":"O"}

# %%
# This file is from the PDBbind database (http://www.pdbbind.org.cn/).
lines = read_file(open("./data/supplementary/INDEX_general_PL_data.2020", "r"))
PDBbind_labels_dict = preprocessing_PDBbind(lines, PDB_ligand_isomeric_dict, amino_acids_short)
print(f"PDBbind labels: {len(PDBbind_labels_dict)}")
# Out:
# PDBbind labels: 16148

# %% [markdown]
# #### 2.1 CSAR2014 and CSAR2012 dataset

# %%
#This file is from the CSAR database (www.csardock.org).
CSAR2014_info = pd.read_csv("./data/supplementary/CSAR2014_labels.csv", sep = ",")
CSAR2012_info = pd.read_csv("./data/supplementary/CSAR2012_labels.csv", sep = ",")

# %%
def make_df(df, ligand_stereo_dict, amino_acids_short):
    results = {"PDB":[], "Lig_code":[], "Labels":[], "OE_stereo_SMILES":[], "Measure":[], "Potency":[], "Unit":[]}
    
    for line in df.values:
        pdb, ligand_code, measure, potency, unit, label = line[2], line[3], line[5], line[6], line[7], line[8]  
        
        if ligand_code not in ligand_stereo_dict:
            continue
        
        elif ligand_code in amino_acids_short:
            continue
        
        else:
            results["PDB"].append(pdb.lower())
            results["Lig_code"].append(ligand_code)
            results["Labels"].append(label)
            results["OE_stereo_SMILES"].append(ligand_stereo_dict[ligand_code])
            results["Measure"].append(measure)
            results["Potency"].append(potency)
            results["Unit"].append(unit)
            
    return pd.DataFrame(results)

# %%
CSAR2014_df = make_df(CSAR2014_info,  PDB_ligand_isomeric_dict, amino_acids_short)
CSAR2014_list = CSAR2014_df.PDB.values
print(f"CSAR2014 set: {len(CSAR2014_list)}")
# Out:
# CSAR2014 set: 46

# %%
CSAR2012_df = make_df(CSAR2012_info, PDB_ligand_isomeric_dict, amino_acids_short)
CSAR2012_list = CSAR2012_df.PDB.values
print(f"CSAR2012 set: {len(CSAR2012_list)}")
# Out:
# CSAR2012 set: 55

# %% [markdown]
# #### 2.2 CSARset1 and CSARset2 dataset

# %%
#This file is from the CSAR database (www.csardock.org). 
CSARset1_raw_info = read_file(open("./data/supplementary/set1.csv", "r"))
CSARset2_raw_info = read_file(open("./data/supplementary/set2.csv", "r"))

# %%
def preprocessing_HiQ(lines):
    data = dict()
    
    for idx, val in enumerate(lines[1:]):
        line_list = val.strip().split(",")
        data[line_list[1].strip()] = [line_list[0].strip(), line_list[2].strip(), line_list[3].strip()]
    return data

# %%
CSARset1_dict = preprocessing_HiQ(CSARset1_raw_info)
CSARset2_dict = preprocessing_HiQ(CSARset2_raw_info)

# %%
def make_df(info_dict, ligand_stereo_dict, amino_acids_short):
    results = {"PDB":[], "Lig_code":[], "Labels":[], "OE_stereo_SMILES":[]}
    
    for pdbid in list(info_dict.keys()):
        label, ligand_code = info_dict[pdbid][1], info_dict[pdbid][2] 
        
        if ligand_code not in ligand_stereo_dict:
            continue
            
        elif ligand_code in amino_acids_short:
            continue

        else:
            results["PDB"].append(pdbid)
            results["Lig_code"].append(ligand_code)
            results["Labels"].append(label)
            results["OE_stereo_SMILES"].append(ligand_stereo_dict[ligand_code])            

    return pd.DataFrame(results)

# %%
CSARset1_df = make_df(CSARset1_dict, PDB_ligand_isomeric_dict, amino_acids_short)
CSARset1_list = CSARset1_df.PDB.values
print(f"CSARset1 set: {len(CSARset1_list)}")
# Out:
# CSARset1 set: 161

# %%
CSARset2_df = make_df(CSARset2_dict, PDB_ligand_isomeric_dict, amino_acids_short)
CSARset2_list = CSARset2_df.PDB.values
print(f"CSARset2 set: {len(CSARset2_list)}")
# Out:
# CSARset2 set: 149

# %% [markdown]
# #### 2.3 Astex dataset

# %%
# This file is from the original paper (https://doi.org/10.1021/jm061277y) and we have modified the data by cross-check it with the PDB database.
Astex_info = pd.read_csv("./data/supplementary/Astex_labels.csv", sep = "\t")

# %%
def make_df(df, ligand_stereo_dict, amino_acids_short):
    results = {"PDB":[], "Lig_code":[], "Labels":[], "OE_stereo_SMILES":[], "Measure":[], "Potency":[], "Unit":[]}
    
    for line in df.values:
        pdb, ligand_code, measure, potency, unit, label = line[0], line[3], line[4], line[5], line[6], line[8]

        if ligand_code not in ligand_stereo_dict:
            continue
        
        elif ligand_code in amino_acids_short:
            continue
            
        else:
            results["PDB"].append(pdb)
            results["Lig_code"].append(ligand_code)
            results["Labels"].append(label)
            results["OE_stereo_SMILES"].append(ligand_stereo_dict[ligand_code])
            results["Measure"].append(measure)
            results["Potency"].append(potency)
            results["Unit"].append(unit)
            
    return pd.DataFrame(results)

# %%
Astex_df = make_df(Astex_info, PDB_ligand_isomeric_dict, amino_acids_short)
Astex_list = Astex_df.PDB.values
print(f"Astex set: {len(Astex_list)}")
# Out:
# Astex set: 75

# %% [markdown]
# #### 2.4 COACH420 dataset

# %%
def load_ligand_info(path):
    
    results = dict()
    
    lines = open(path, "r").readlines()
    
    for line in lines:
        if "#" not in line:
            line = line.strip()
            if line != "":
                line_list = line.split("  ")
                pdb = line_list[0].split("/")[1][:-4]
                lig_list = line_list[1].split(",")

                tmp = list()
                for i in lig_list:
                    if i not in amino_acids_short:
                        tmp.append(i.strip())

                if len(tmp) != 0:
                    results[pdb] = tmp            
    
    return results

# %%
#This file is from the P2Rank github (https://github.com/rdk/p2rank).
COACH420_ligand_dict = load_ligand_info("./data/supplementary/COACH420_ligand_code.txt")

# %%
def make_df(input_dict, ligand_stereo_dict, amino_acids_short):
    results = {"PDB":[], "Lig_code":[], "COACH420_chain":[], "OE_stereo_SMILES":[]}
    
    for pdbid_chain in list(input_dict.keys()):
        pdbid, chain, ligand_code_list = pdbid_chain[:-1], pdbid_chain[-1:], input_dict[pdbid_chain]
        
        for lig_code in ligand_code_list:
            
            if f"{pdbid}_{lig_code}" not in ["2vu9_GAL",  # problem in graph preprocessing
                                            "1awf_TYS", "1c5o_BAM", "1c5p_BAM", "1ett_0ZG", "1f5k_BAM", "1i72_PUT", "1j37_MCO", "1qhr_TYS", "1qj1_TYS", "1qj6_TYS", "1qj7_TYS", "2qwe_GNA"]: 
                if lig_code not in ligand_stereo_dict:
                    continue

                elif lig_code in amino_acids_short:
                    continue            

                else:
                    results["PDB"].append(pdbid)
                    results["Lig_code"].append(lig_code)
                    results["COACH420_chain"].append(chain)
                    results["OE_stereo_SMILES"].append(ligand_stereo_dict[lig_code])

    return pd.DataFrame(results)

# %%
COACH420_df = make_df(COACH420_ligand_dict, PDB_ligand_isomeric_dict, amino_acids_short)
COACH420_list = COACH420_df.PDB.values
print(f"COACH420 set: {len(COACH420_list)}")
# Out:
# COACH420 set: 367

# %% [markdown]
# #### 2.5 HOLO4K dataset

# %%
# This file is from the P2Rank github (https://github.com/rdk/p2rank).
HOLO4K_ligand_dict = load_ligand_info("./data/supplementary/HOLO4K_ligand_code.txt")

# %%
def make_df(input_dict, ligand_stereo_dict, amino_acids_short):
    results = {"PDB":[], "Lig_code":[], "OE_stereo_SMILES":[]}

    for pdbid in list(input_dict.keys()):
        ligand_code_list = input_dict[pdbid]    
        for lig_code in ligand_code_list:
            
            if f"{pdbid}_{lig_code}" not in ['1nx8_N7P', # problem in graph preprocessing
                                            "1awf_TYS", "1c5o_BAM", "1c5p_BAM", "1ett_0ZG", "1f5k_BAM", "1i72_PUT", "1j37_MCO", "1qhr_TYS", "1qj1_TYS", "1qj6_TYS", "1qj7_TYS", "2qwe_GNA"]:  
                if lig_code not in ligand_stereo_dict:
                    continue

                elif lig_code in amino_acids_short:
                    continue    

                else:
                    results["PDB"].append(pdbid)
                    results["Lig_code"].append(lig_code)
                    results["OE_stereo_SMILES"].append(ligand_stereo_dict[lig_code])

    return pd.DataFrame(results)

# %%
HOLO4K_df = make_df(HOLO4K_ligand_dict, PDB_ligand_isomeric_dict, amino_acids_short)
HOLO4K_list = HOLO4K_df.PDB.values
print(f"HOLO4K set: {len(HOLO4K_list)}")
# Out:
# HOLO4K set: 4314

# %% [markdown]
# #### 2.6 CASF2016 and CASF2013 dataset

# %%
def make_df(labels_dict, complex_list, ligand_stereo_dict):
    results = {"PDB":[], "Lig_code":[], "Labels":[], "OE_stereo_SMILES":[], "Measure":[], "Potency":[], "Unit":[]}
    
    for pdbid in complex_list:
        
        if pdbid in labels_dict:
            data = labels_dict[pdbid]
            
            if f"{pdbid}_{data[-1]}" not in ['1gbt_GBS', '5g0q_IF6', '3rxj_GBS', '3rme_RME', '2gss_EAA']: # problem in graph preprocessing
                results["PDB"].append(pdbid)
                results["Lig_code"].append(data[-1])
                results["Labels"].append(data[-2])
                results["OE_stereo_SMILES"].append(ligand_stereo_dict[data[-1]])          
                results["Measure"].append(data[1])
                results["Potency"].append(data[2])
                results["Unit"].append(data[3])
        
    return pd.DataFrame(results)

# %%
CASF2016_list = [i.strip() for i in read_file(open("./data/supplementary/CASF2016_list.txt", "r"))]
CASF2016_df = make_df(PDBbind_labels_dict, CASF2016_list, PDB_ligand_isomeric_dict)
CASF2016_list = CASF2016_df.PDB.values
print(f"CASF2016 set: {len(CASF2016_list)}")
# Out:
# CASF2016 set: 279

# %%
CASF2013_list = [i.strip() for i in read_file(open("./data/supplementary/CASF2013_list.txt", "r"))]
CASF2013_df = make_df(PDBbind_labels_dict, CASF2013_list, PDB_ligand_isomeric_dict)
CASF2013_list = CASF2013_df.PDB.values
print(f"CASF2013 set: {len(CASF2013_list)}")
# Out:
# CASF2013 set: 180

# %% [markdown]
# #### 2.7 PDBbind dataset

# %%
# This file is from the PDBbind database (http://www.pdbbind.org.cn/).
general_set_except_refined_set_list = [i.strip() for i in read_file(open("./data/supplementary/PDBbind_2020_general_list.txt", "r"))]
refiend_set_list = [i.strip() for i in read_file(open("./data/supplementary/PDBbind_2020_refined_list.txt", "r"))]

# %%
total_set_list = list(set(general_set_except_refined_set_list) | set(refiend_set_list))
print(f"total set: {len(total_set_list)}")
# Out:
# total set: 19443

# %%
PDBbind_list = list(set(total_set_list) - set(CASF2016_list) - set(CASF2013_list) - set(CSAR2014_list) - set(CSAR2012_list) - set(CSARset1_list) - set(CSARset2_list) - set(Astex_list) - set(COACH420_list) - set(HOLO4K_list))
PDBbind_df = make_df(PDBbind_labels_dict, PDBbind_list, PDB_ligand_isomeric_dict)
print(f"PDBbind training set: {len(PDBbind_df)}")
# Out:
# PDBbind training set: 14725

# %% [markdown]
# ### 3. Convert SMILES

# %% [markdown]
# #### 3.1  PDBbind dataset

# %%
def convert_rdkit_smiles(df, isomeric = False):
    
    results = list()

    for line in df.values:
        try:
            smiles = MolToSmiles(MolFromSmiles(line[3]),isomericSmiles = isomeric, kekuleSmiles = True)
            results.append(smiles)
        except:
            results.append(None)
    return results

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(PDBbind_df, isomeric = True)
# Out:
# [21:49:51] Explicit valence for atom # 24 N, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 6 N, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 25 N, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 2 O, 3, is greater than permitted
# [21:49:51] Explicit valence for atom # 10 N, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 0 B, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 10 N, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 0 B, 5, is greater than permitted
# [21:49:51] Explicit valence for atom # 28 N, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 6 N, 4, is greater than permitted
# [21:49:51] Explicit valence for atom # 0 B, 6, is greater than permitted
# [21:49:52] Explicit valence for atom # 11 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 3 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 0 B, 6, is greater than permitted
# [21:49:52] Explicit valence for atom # 10 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 0 B, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 16 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 0 B, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 6 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 6 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 59 C, 5, is greater than permitted
# [21:49:52] WARNING: not removing hydrogen atom without neighbors
# [21:49:52] WARNING: not removing hydrogen atom without neighbors
# [21:49:52] WARNING: not removing hydrogen atom without neighbors
# [21:49:52] Explicit valence for atom # 0 B, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 2 O, 3, is greater than permitted
# [21:49:52] Explicit valence for atom # 28 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 11 C, 5, is greater than permitted
# [21:49:52] Explicit valence for atom # 0 B, 5, is greater than permitted
# [21:49:52] Explicit valence for atom # 13 N, 4, is greater than permitted
# [21:49:52] Explicit valence for atom # 15 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [21:49:53] Explicit valence for atom # 44 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 30 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 4 O, 3, is greater than permitted
# [21:49:53] Explicit valence for atom # 14 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 17 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 49 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 30 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 40 O, 3, is greater than permitted
# [21:49:53] Explicit valence for atom # 10 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 7 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 0 B, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 2 O, 3, is greater than permitted
# [21:49:53] Explicit valence for atom # 10 C, 5, is greater than permitted
# [21:49:53] Explicit valence for atom # 16 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 7 O, 3, is greater than permitted
# [21:49:53] Explicit valence for atom # 28 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 2 O, 3, is greater than permitted
# [21:49:53] Explicit valence for atom # 6 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 6 N, 4, is greater than permitted
# [21:49:53] Explicit valence for atom # 0 B, 5, is greater than permitted
# [21:49:54] Explicit valence for atom # 10 N, 4, is greater than permitted
# [21:49:54] Explicit valence for atom # 13 N, 4, is greater than permitted

# %%
PDBbind_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
PDBbind_df = PDBbind_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[PDBbind] complexes: {len(PDBbind_df)}")
# Out:
# [PDBbind] complexes: 14673

# %% [markdown]
# #### 3.2  CASF2016 dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(CASF2016_df, isomeric = True)

# %%
CASF2016_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
CASF2016_df = CASF2016_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[CASF2016] complexes: {len(CASF2016_df)}")
# Out:
# [CASF2016] complexes: 279

# %% [markdown]
# #### 3.3  CASF2013 dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(CASF2013_df, isomeric = True)

# %%
CASF2013_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
CASF2013_df = CASF2013_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[CASF2013] complexes: {len(CASF2013_df)}")
# Out:
# [CASF2013] complexes: 180

# %% [markdown]
# #### 3.4  CSAR2014 dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(CSAR2014_df, isomeric = True)

# %%
CSAR2014_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
CSAR2014_df = CSAR2014_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[CSAR2014] complexes: {len(CSAR2014_df)}")
# Out:
# [CSAR2014] complexes: 46

# %% [markdown]
# #### 3.5  CSAR2012 dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(CSAR2012_df, isomeric = True)

# %%
CSAR2012_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
CSAR2012_df = CSAR2012_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[CSAR2012] complexes: {len(CSAR2012_df)}")
# Out:
# [CSAR2012] complexes: 55

# %% [markdown]
# #### 3.6  CSARset1 dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(CSARset1_df, isomeric = True)

# %%
CSARset1_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
CSARset1_df = CSARset1_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[CSARset1] complexes: {len(CSARset1_df)}")
# Out:
# [CSARset1] complexes: 161

# %% [markdown]
# #### 3.7  CSARset2 dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(CSARset2_df, isomeric = True)

# %%
CSARset2_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
CSARset2_df = CSARset2_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[CSARset2] complexes: {len(CSARset2_df)}")
# Out:
# [CSARset2] complexes: 149

# %% [markdown]
# #### 3.8  Astex dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(Astex_df, isomeric = True)

# %%
Astex_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
Astex_df = Astex_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[Astex] complexes: {len(Astex_df)}")
# Out:
# [Astex] complexes: 75

# %% [markdown]
# #### 3.9 COACH420 dataset

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(COACH420_df, isomeric = True)

# %%
COACH420_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
COACH420_df = COACH420_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[COACH420] complexes: {len(COACH420_df)}")
# Out:
# [COACH420] complexes: 367

# %% [markdown]
# #### 3.10 HOLO4K dataset

# %%
def convert_rdkit_smiles(df, isomeric = False):
    
    results = list()

    for line in df.values:
        try:
            smiles = MolToSmiles(MolFromSmiles(line[2]),isomericSmiles = isomeric, kekuleSmiles = True)
            results.append(smiles)
        except:
            results.append(None)
    return results

# %%
rdkit_smiles_isomeric = convert_rdkit_smiles(HOLO4K_df, isomeric = True)
# Out:
# [21:50:00] Explicit valence for atom # 0 Be, 3, is greater than permitted
# [21:50:00] Explicit valence for atom # 0 Be, 4, is greater than permitted
# [21:50:00] Explicit valence for atom # 0 Be, 3, is greater than permitted
# [21:50:00] Explicit valence for atom # 0 Be, 4, is greater than permitted
# [21:50:00] Explicit valence for atom # 0 Be, 3, is greater than permitted
# [21:50:00] Explicit valence for atom # 4 O, 3, is greater than permitted
# [21:50:00] Explicit valence for atom # 3 O, 3, is greater than permitted
# [21:50:00] Explicit valence for atom # 7 Cl, 5, is greater than permitted

# %%
HOLO4K_df["RDKit_iso_SMILES"] = rdkit_smiles_isomeric

# %%
HOLO4K_df = HOLO4K_df.dropna(axis = 0).reset_index(drop=True)

# %%
print(f"[HOLO4K] complexes: {len(HOLO4K_df)}")
# Out:
# [HOLO4K] complexes: 4306

# %% [markdown]
# ### 4. Save data

# %%
PDBbind_df = PDBbind_df[["PDB", "Lig_code", "Labels", "OE_stereo_SMILES", "RDKit_iso_SMILES", "Measure", "Potency", "Unit"]]
CASF2016_df = CASF2016_df[["PDB", "Lig_code", "Labels", "OE_stereo_SMILES", "RDKit_iso_SMILES", "Measure", "Potency", "Unit"]]
CASF2013_df = CASF2013_df[["PDB", "Lig_code", "Labels", "OE_stereo_SMILES", "RDKit_iso_SMILES", "Measure", "Potency", "Unit"]]
CSAR2014_df = CSAR2014_df[["PDB", "Lig_code", "Labels", "OE_stereo_SMILES", "RDKit_iso_SMILES", "Measure", "Potency", "Unit"]]
CSAR2012_df = CSAR2012_df[["PDB", "Lig_code", "Labels", "OE_stereo_SMILES", "RDKit_iso_SMILES", "Measure", "Potency", "Unit"]]
Astex_df = Astex_df[["PDB", "Lig_code", "Labels", "OE_stereo_SMILES", "RDKit_iso_SMILES", "Measure", "Potency", "Unit"]]

# %%
PDBbind_df.to_csv("./preprocessed_data/step1_PDBbind_data.tsv", sep = "\t", index = False)
CASF2016_df.to_csv("./preprocessed_data/step1_CASF2016_data.tsv", sep = "\t", index = False)
CASF2013_df.to_csv("./preprocessed_data/step1_CASF2013_data.tsv", sep = "\t", index = False)
CSAR2014_df.to_csv("./preprocessed_data/step1_CSAR2014_data.tsv", sep = "\t", index = False)
CSAR2012_df.to_csv("./preprocessed_data/step1_CSAR2012_data.tsv", sep = "\t", index = False)
CSARset1_df.to_csv("./preprocessed_data/step1_CSARset1_data.tsv", sep = "\t", index = False)
CSARset2_df.to_csv("./preprocessed_data/step1_CSARset2_data.tsv", sep = "\t", index = False)
Astex_df.to_csv("./preprocessed_data/step1_Astex_data.tsv", sep = "\t", index = False)
COACH420_df.to_csv("./preprocessed_data/step1_COACH420_data.tsv", sep = "\t", index = False)
HOLO4K_df.to_csv("./preprocessed_data/step1_HOLO4K_data.tsv", sep = "\t", index = False)

# %% [markdown]
# ### 5. Download PDB and Ideal ligand structure

# %%
PDBbind_PDB, CASF2016_PDB, CASF2013_PDB, CSAR2014_PDB, CASR2012_PDB, CSARset1_PDB, CSARset2_PDB, Astex_PDB, COACH420_PDB, HOLO4K_PDB = PDBbind_df.iloc[:,0].values, CASF2016_df.iloc[:,0].values, CASF2013_df.iloc[:,0].values, CSAR2014_df.iloc[:,0].values, CSAR2012_df.iloc[:,0].values, CSARset1_df.iloc[:,0].values, CSARset2_df.iloc[:,0].values, Astex_df.iloc[:,0].values, COACH420_df.iloc[:,0].values, HOLO4K_df.iloc[:,0].values
PDBbind_LIG, CASF2016_LIG, CASF2013_LIG, CSAR2014_LIG, CASR2012_LIG, CSARset1_LIG, CSARset2_LIG, Astex_LIG, COACH420_LIG, HOLO4K_LIG = PDBbind_df.iloc[:,1].values, CASF2016_df.iloc[:,1].values, CASF2013_df.iloc[:,1].values, CSAR2014_df.iloc[:,1].values, CSAR2012_df.iloc[:,1].values, CSARset1_df.iloc[:,1].values, CSARset2_df.iloc[:,1].values, Astex_df.iloc[:,1].values, COACH420_df.iloc[:,1].values, HOLO4K_df.iloc[:,1].values

# %%
PDB_list = np.concatenate((PDBbind_PDB, CASF2016_PDB, CASF2013_PDB, CSAR2014_PDB, CASR2012_PDB, CSARset1_PDB, CSARset2_PDB, Astex_PDB, COACH420_PDB, HOLO4K_PDB))
LIG_list = np.concatenate((PDBbind_LIG, CASF2016_LIG, CASF2013_LIG, CSAR2014_LIG, CASR2012_LIG, CSARset1_LIG, CSARset2_LIG, Astex_LIG, COACH420_LIG, HOLO4K_LIG))

# %%
print(f"Unique PDB: {len(np.unique(PDB_list))}, Unique Ligand: {len(np.unique(LIG_list))}")
# Out:
# Unique PDB: 19013, Unique Ligand: 13352

# %%
PDB_df = pd.DataFrame({"PDB":[i for i in np.unique(PDB_list)]})
LIG_df = pd.DataFrame({"LIG":[i for i in np.unique(LIG_list)]})

# %%
PDB_df
# Out:
#         PDB
# 0      10gs
# 1      121p
# 2      12as
# 3      13gs
# 4      13pk
# ...     ...
# 19008  9gss
# 19009  9hvp
# 19010  9icd
# 19011  9ldb
# 19012  9ldt
#
# [19013 rows x 1 columns]

# %%
LIG_df
# Out:
#        LIG
# 0      001
# 1      002
# 2      003
# 3      006
# 4      007
# ...    ...
# 13347  ZZO
# 13348  ZZP
# 13349  ZZQ
# 13350  ZZX
# 13351  ZZY
#
# [13352 rows x 1 columns]

# %%
def parallelize_dataframe(df, func, num_partitions=5):
    df_split = np.array_split(df, num_partitions)
    pool = Pool(num_partitions)
    results = pool.map(func, df_split)
    pool.close()
    pool.join()
    return results

# %%
def download_PDB_structure(pdb):
    if not os.path.isfile(f"./data/PDB/protein/{pdb}.pdb"):
        command = f"wget https://files.rcsb.org/download/{pdb}.pdb --directory-prefix={path}"
        os.system(command)

# %%
def get_pdb_info_bulk(df):
    return df.PDB.map(download_PDB_structure)

# %%
path = "./data/PDB/protein"

# %%
_ = parallelize_dataframe(PDB_df, get_pdb_info_bulk, 10)
# Out:
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/10gs.pdb
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/182l.pdb
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/17gs.pdb
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/13pk.pdb
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/183l.pdb
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/16pk.pdb
# Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... --2024-09-04 21:50:04--  https://files.rcsb.org/download/12as.pdb
# Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... --2024-09-04 21:50:04--  https://files.rcsb.org/download/121p.pdb
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/13gs.pdb
# --2024-09-04 21:50:04--  https://files.rcsb.org/download/184l.pdb
# Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# 128.6.159.100
# 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/13gs.pdb’
#
#      0K ........200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/183l.pdb’
#
#      0K .......... .......... .......... .... .......... .......... .................. ..........  126K
#     50K .......... .......... .......... ........ ..........  124K
#     50K .......... .......... .......... .......... ........ ..........  253K
#    100K .......... .......... .......... .......... .......... 15.1M
#    150K .......... .......... .......... .......... .......... 9.84M....  249K
#    100K .......... .......... .......... .......... .....      18.8M=0.6s
#
# 2024-09-04 21:50:05 (239 KB/s) - ‘./data/PDB/protein/183l.pdb’ saved [148959]
#
#
#    200K .......... .......... .......... .......... ..........  260K
#    250K .......... .......... .......... .......... .......... 9.88M
#    300K .......... .......... .........                        13.3M=0.8s
#
# 2024-09-04 21:50:05 (410 KB/s) - ‘./data/PDB/protein/13gs.pdb’ saved [337041]
#
# 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/16pk.pdb’
#
#      0K ........200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/12as.pdb’
#
#      0K ........200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/182l.pdb’
#
#      0K ........200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/10gs.pdb’
#
#      0K .......... .......... .......... ..200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/121p.pdb’
#
#      0K .......... .......... .......... .... .......... .......... .... .......... .......... .......................... ..........  125K
#     50K .......... .......... .......... .......... .......... .......... .......... ..........  124K
#     50K .......... .......... .......... ........200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/17gs.pdb’
#
#      0K ........ ..........  122K
#     50K .......... .......... .......... ..........  121K
#     50K .......... .......... .. ................200 OK
#  .......Length: unspecified [application/octet-stream]
# .Saving to: ‘./data/PDB/protein/13pk.pdb’
#
#      0K .......... ..........  248K
#    100K .......... .......... .......... .......... .......... 11.1M
#    150K .......... .......... .......... .......... .......... 12.2M........ .......... ..........  245K
#    100K ......  122K
#     50K .......... .......... ................ .. ................ .......... .......... .......... 6.04M
#    150K .......... .......... .......... .......... .......... 12.1M.. ......200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/protein/184l.pdb’
#
#      0K ............ .......... .... ..........  246K
#    100K .......... .......... .......... ........ ..........  245K
#    100K .......... ...... ......     8.58M=0.6s
#
# 2024-09-04 21:50:06 (237 KB/s) - ‘./data/PDB/protein/182l.pdb’ saved [150012]
#
# ........ .......... .......... ...... .......... .......... ........ 7.87M
#    150K ..
#    200K .......... .......... .......... .......... ..........  255K
#    250K .......... .......... .......... .......... .......... 12.0M
#    300K .......... .......... .......... ....                  11.5M=0.8s
#
# 2024-09-04 21:50:06 (411 KB/s) - ‘./data/PDB/protein/16pk.pdb’ saved [342387]
#
#
#    200K .......... ........ ..........  246K
#    100K .......... .......... .......... .......... .......... 10.1M
#    150K ...... .......... .......... ............                                                 2.25M=0.6s
#
# 2024-09-04 21:50:06 (252 KB/s) - ‘./data/PDB/protein/121p.pdb’ saved [160542]
#
# ..  251K
#    250K .......... .......... .......... .......... .......... 11.8M
#    300K .......... .......... .......... .......... .......... 10.2M
#    350K .......... .......... .......... .......... .......... 11.7M
#    400K .......... .............. ..........  118K
#     50K .......... .......... .......... .......... .......... .......... .......... .......... .......... .......... ..........  244K
#    200K .......... .......... .......... .......... .......... 9.89M
#    250K .......... .......... .......... .......... .............. ............ 9.76M
#    300K ......  119K
#     50K .......... .......... ................ ........                                    4.47M=0.8s
#
# 2024-09-04 21:50:06 (379 KB/s) - ‘./data/PDB/protein/10gs.pdb’ saved [326511]
#
#  ............ .......... .......... ..........  274K
#    450K .......... .......... ...                              4.12M=1.0s
#
# 2024-09-04 21:50:06 (463 KB/s) - ‘./data/PDB/protein/12as.pdb’ saved [484380]
#
# .. ..........  245K
#    100K .......... .......... .......... .......... .......... 12.5M
#    150K .......... .......... .......... .......... .................. 10.1M ..........  117K
#     50K .......... .......... .......... .......... ..........  247K
#    100K .......... .......... .......... .......... .......... 9.96M
#    150K .......... .......... .......... .......... .......... 12.4M
#    200K .......... .......... .......... .......... ..........  250K
#    250K .......... .......... .......... .......... .......... 11.8M
#    300K .......... .......... .                                10.6M=0.8s
#
# 2024-09-04 21:50:07 (381 KB/s) - ‘./data/PDB/protein/17gs.pdb’ saved [329184]
#
# .. ..........  240K
#    100K .......... .......... .......... .......... ....       12.4M=0.6s
#
# 2024-09-04 21:50:07 (226 KB/s) - ‘./data/PDB/protein/184l.pdb’ saved [148311]
#
#
#    200K .......... .......... .......... .......... ..........  250K
#    250K .......... .......... .......... .......... .......... 13.0M
#    300K .......... .......... .......... .......... .......... 11.6M
#    350K .......... .......... .......... .......... .......... 12.1M
#    400K .......... .......... .......... .......... ..........  263K
#    450K .......... .......... .......... .......... .......... 12.3M
#    500K .......... .......... .......... .......... .......... 12.2M
#    550K .......... .......... .......... .......... .......... 10.0M
#    600K .......... .......... .......... .......... .......... 12.2M
#    650K .......... .......... .......... .......... .......... 9.91M
#    700K .......... .......... .......... .......... .......... 11.9M
#    750K .......... .......... .......... .......... .......... 12.0M
#    800K .......... .......... .......... .......... ..........  291K
#    850K .......... .......... .......... .......... .......... 12.1M
#    900K .......... .......... .......... .......... .......... 12.2M
#    950K .......... .......... .......... .......... .......... 10.1M
#   1000K .......... .......... .......... .......... .......... 11.9M
#   1050K .......... .......... .......... .......... .......... 10.2M
#   1100K .......... .......... ........                         13.5M=1.3s
#
# 2024-09-04 21:50:07 (895 KB/s) - ‘./data/PDB/protein/13pk.pdb’ saved [1155951]

# %%
def download_ligand_structure(lig):
    if not os.path.isfile(f"./data/PDB/ligand/{lig}_ideal.pdb"):
        #command = f"wget https://files.rcsb.org/ligands/download/{lig}_ideal.pdb --directory-prefix={path}"
        command = f"wget https://files.rcsb.org/ligands/{lig[0]}/{lig}/{lig}_ideal.pdb --directory-prefix={path}"
        os.system(command)
    
    if not os.path.isfile(f"./data/PDB/ligand/{lig}_ideal.sdf"):
        command = f"wget https://files.rcsb.org/ligands/download/{lig}_ideal.sdf --directory-prefix={path}"
        os.system(command)

# %%
def get_ligand_info_bulk(df):
    return df.LIG.map(download_ligand_structure)

# %%
path = "./data/PDB/ligand/"

# %%
_ = parallelize_dataframe(LIG_df, get_ligand_info_bulk, 10)
# Out:
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/002/002_ideal.pdb
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/001/001_ideal.pdb
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/003/003_ideal.pdb
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/006/006_ideal.pdb
# Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/007/007_ideal.pdb
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/00G/00G_ideal.pdb
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/009/009_ideal.pdb
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/00L/00L_ideal.pdb
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/00N/00N_ideal.pdb
# 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/0/00K/00K_ideal.pdb
# 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# 128.6.159.100Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443...
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 5905 (5.8K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/003_ideal.pdb’
#
#      0K .....                                                 100%  815M=0s
#
# 2024-09-04 21:50:10 (815 MB/s) - ‘./data/PDB/ligand/003_ideal.pdb’ saved [5905/5905]
#
# 200 OK
# Length: 3158 (3.1K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/00G_ideal.pdb’
#
#      0K ...                                                   100%  673M=0s
#
# 2024-09-04 21:50:10 (673 MB/s) - ‘./data/PDB/ligand/00G_ideal.pdb’ saved [3158/3158]
#
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/003_ideal.sdf
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/00G_ideal.sdf
# Resolving files.rcsb.org (files.rcsb.org)... Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 200 OK
# Length: 8733 (8.5K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/006_ideal.pdb’
#
#      0K ........                                              100% 98.3M=0s
#
# 2024-09-04 21:50:10 (98.3 MB/s) - ‘./data/PDB/ligand/006_ideal.pdb’ saved [8733/8733]
#
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/006_ideal.sdf
# Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 200 OK
# Length: 8521 (8.3K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/00L_ideal.pdb’
#
#      0K ........                                              100%  115M=0s
#
# 2024-09-04 21:50:10 (115 MB/s) - ‘./data/PDB/ligand/00L_ideal.pdb’ saved [8521/8521]
#
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/00L_ideal.sdf
# Resolving files.rcsb.org (files.rcsb.org)... 200 OK
# Length: 6774 (6.6K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/002_ideal.pdb’
#
#      0K ......                                                100% 1.07G=0s
#
# 2024-09-04 21:50:10 (1.07 GB/s) - ‘./data/PDB/ligand/002_ideal.pdb’ saved [6774/6774]
#
# 200 OK
# Length: 7107 (6.9K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/00N_ideal.pdb’
#
#      0K ......                                                100% 1.07G=0s
#
# 2024-09-04 21:50:10 (1.07 GB/s) - ‘./data/PDB/ligand/00N_ideal.pdb’ saved [7107/7107]
#
# 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 200 OK
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/002_ideal.sdf
# Length: 3047 (3.0K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/007_ideal.pdb’
#
#      0K ..                                                    100%  675M=0s
#
# 2024-09-04 21:50:10 (675 MB/s) - ‘./data/PDB/ligand/007_ideal.pdb’ saved [3047/3047]
#
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/00N_ideal.sdf
# 200 OK
# Length: 8935 (8.7K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/009_ideal.pdb’
# Resolving files.rcsb.org (files.rcsb.org)...
#      0K ........                                              100% 17.3M=0s
#
# 2024-09-04 21:50:10 (17.3 MB/s) - ‘./data/PDB/ligand/009_ideal.pdb’ saved [8935/8935]
#
# Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/007_ideal.sdf
# Resolving files.rcsb.org (files.rcsb.org)... --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/009_ideal.sdf
# 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... 200 OK
# Length: 8824 (8.6K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/001_ideal.pdb’
#
#      0K ........                                              100%  189M=0s
#
# 2024-09-04 21:50:10 (189 MB/s) - ‘./data/PDB/ligand/001_ideal.pdb’ saved [8824/8824]
#
# 200 OK
# Length: 8319 (8.1K) [chemical/x-pdb]
# Saving to: ‘./data/PDB/ligand/00K_ideal.pdb’
#
#      0K ........                                              100%  130M=0s
#
# 2024-09-04 21:50:10 (130 MB/s) - ‘./data/PDB/ligand/00K_ideal.pdb’ saved [8319/8319]
#
# --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/001_ideal.sdf
# Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... --2024-09-04 21:50:10--  https://files.rcsb.org/ligands/download/00K_ideal.sdf
# Resolving files.rcsb.org (files.rcsb.org)... 128.6.159.100
# Connecting to files.rcsb.org (files.rcsb.org)|128.6.159.100|:443... connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/006_ideal.sdf’
#
#      0K ........                                               81.2M=0s
#
# 2024-09-04 21:50:11 (81.2 MB/s) - ‘./data/PDB/ligand/006_ideal.sdf’ saved [8546]
#
# 200 OK
# Length: 3076 (3.0K) [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/007_ideal.sdf’
#
#      0K ...                                                   100%  707M=0s
#
# 2024-09-04 21:50:11 (707 MB/s) - ‘./data/PDB/ligand/007_ideal.sdf’ saved [3076/3076]
#
# 200 OK
# Length: 3212 (3.1K) [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/00G_ideal.sdf’
#
#      0K ...                                                   100%  305M=0s
#
# 2024-09-04 21:50:11 (305 MB/s) - ‘./data/PDB/ligand/00G_ideal.sdf’ saved [3212/3212]
#
# 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/00L_ideal.sdf’
#
#      0K ........                                               74.9M=0s
#
# 2024-09-04 21:50:11 (74.9 MB/s) - ‘./data/PDB/ligand/00L_ideal.sdf’ saved [8329]
#
# 200 OK
# Length: 5829 (5.7K) [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/003_ideal.sdf’
#
#      0K .....                                                 100% 1.60G=0s
#
# 2024-09-04 21:50:11 (1.60 GB/s) - ‘./data/PDB/ligand/003_ideal.sdf’ saved [5829/5829]
#
# 200 OK
# Length: 6648 (6.5K) [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/002_ideal.sdf’
#
#      0K ......                                                100% 1.42G=0s
#
# 2024-09-04 21:50:11 (1.42 GB/s) - ‘./data/PDB/ligand/002_ideal.sdf’ saved [6648/6648]
#
# 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/009_ideal.sdf’
#
#      0K ........                                               78.0M=0s
#
# 2024-09-04 21:50:11 (78.0 MB/s) - ‘./data/PDB/ligand/009_ideal.sdf’ saved [8700]
#
# 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/00K_ideal.sdf’
#
#      0K .......                                                42.7M=0s
#
# 2024-09-04 21:50:11 (42.7 MB/s) - ‘./data/PDB/ligand/00K_ideal.sdf’ saved [8115]
#
# 200 OK
# Length: 7020 (6.9K) [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/00N_ideal.sdf’
#
#      0K ......                                                100% 1.51G=0s
#
# 2024-09-04 21:50:11 (1.51 GB/s) - ‘./data/PDB/ligand/00N_ideal.sdf’ saved [7020/7020]
#
# 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘./data/PDB/ligand/001_ideal.sdf’
#
#      0K ........                                               92.7M=0s
#
# 2024-09-04 21:50:11 (92.7 MB/s) - ‘./data/PDB/ligand/001_ideal.sdf’ saved [8582]

# %%
def read_file(file):
    return file.readlines()

def additional_download(df):
    path = "./data/PDB/ligand/"

    for lig in df.values:
        if not os.path.isfile(f"{path}{lig[0]}_ideal.pdb"):
            lines = read_file(open(f"{path}{lig[0]}_ideal.pdb", "r"))

            command = f"wget https://files.rcsb.org/ligands/download/{lig[0]}_ideal.mol2 --directory-prefix={path}"
            os.system(command)

            command = f"obabel -imol2 {path}{lig[0]}_ideal.mol2 -opdb -O {path}{lig[0]}_ideal.pdb"
            os.system(command)

            command = f"obabel -imol2 {path}{lig[0]}_ideal.mol2 -osdf -O {path}{lig[0]}_ideal.sdf"
            os.system(command)

# %%
additional_download(LIG_df)

# %% [markdown]
# ### 6. Check ligand info

# %%
path = "./data/PDB/protein"

# %%
def extract_ligand_info(row):
    pdbid, lig_code, ligand_info = row[0], row[1], list()
    lines = read_file(open(f"{path}/{pdbid}.pdb", "r"))
    
    model_flag = 0
    
    """ Extract ligand info """
    for line in lines:
        if "ANISOU" not in line:
            if line[:5].strip() == "MODEL":
                if model_flag == 1:
                    break
                model_falg = 1
            
            if "HETATM" in line:
                residue, chain, residue_seq_number = line[17:20].strip(), line[21:22].strip(), line[22:26].strip()

                if residue == lig_code:
                    if f"{residue}_{chain}_{residue_seq_number}" not in ligand_info:
                        ligand_info.append(f"{residue}_{chain}_{residue_seq_number}")

    if len(ligand_info) == 0:
        return None
    else:
        return ",".join(ligand_info)

# %%
def extract_ligand_info_bulk(df):
    return df.apply(extract_ligand_info, axis = 1)

# %%
def parallelize_dataframe(df, func, num_partitions=5):
    df_split = np.array_split(df, num_partitions)
    pool = Pool(num_partitions)
    results = pool.map(func, df_split)
    pool.close()
    pool.join()
    return results

# %% [markdown]
# #### 6.1 PDBbind dataset

# %%
PDBbind_ligand_info_results = parallelize_dataframe(PDBbind_df, extract_ligand_info_bulk, 10)

# %%
PDBbind_ligand_info_results = pd.concat(PDBbind_ligand_info_results)

# %%
PDBbind_df["Total_Lig_info"] = PDBbind_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
PDBbind_df = PDBbind_df.dropna(axis = 0).reset_index(drop=True)
PDBbind_df
# Out:
#         PDB Lig_code Labels  \
# 0      5u8a      82D   7.89
# 1      6e1y      HLM   7.66
# 2      6i61      H3W   6.24
# 3      6hub      GRW   8.10
# 4      4hhy      15R   8.72
# ...     ...      ...    ...
# 14538  4bty      JWF   7.70
# 14539  5csh      54E   3.57
# 14540  2pj2      864   7.92
# 14541  4xmo      46G   8.70
# 14542  5dtq      5F6   3.86
#
#                                         OE_stereo_SMILES  \
# 0      Cn1cc(c2c1cccc2)[C@H]3CN(C[C@@H]3N(C)C)Cc4c(cc...
# 1        C[C@@H](c1cccc(c1)Cl)NC(=O)c2cccc(c2)CNC3=NCCN3
# 2                         CCC(C)(c1ccc(cc1)O)c2ccc(cc2)O
# 3      C[C@H]([C@@H](C(=O)N[C@H](CCS(=O)(=O)C)Cc1ccc(...
# 4      c1ccc2c(c1)C(=NNC2=O)Cc3ccc(c(c3)C(=O)N4CCC(CC...
# ...                                                  ...
# 14538  CN1CCN(CC1)c2ccc(cc2)NC3=CC(=O)N(N=C3c4[nH]ncn...
# 14539                           c1ccc(cc1)c2ccc(cc2Cl)CN
# 14540  CC(C)[C@H](NC(=O)OCc1ccccc1)[P@@](=O)(C[C@@H](...
# 14541  Cc1cc(on1)c2cc(c3nnc(n3c2)[C@@](C)(c4ccc5c(c4)...
# 14542            c1cc(c(c(c1)Cl)C(=O)c2ccc3c(c2)cccn3)Cl
#
#                                         RDKit_iso_SMILES Measure Potency  \
# 0      CN(C)[C@H]1CN(CC2=C(F)C=CC=C2Br)C[C@@H]1C1=CN(...      13      nM
# 1      C[C@H](NC(=O)C1=CC=CC(CNC2=NCCN2)=C1)C1=CC=CC(...      22      nM
# 2                   CCC(C)(C1=CC=C(O)C=C1)C1=CC=C(O)C=C1   569.0      nM
# 3      CC(C)C[C@H](NC(=O)[C@@H](CC1=CC=CC=C1)N=[N+]=[...       8      nM
# 4      O=C1NC[C@H]2C3=C1C=CC=C3CCN2C(=O)C1CCN(C(=O)C2...    1.92      nM
# ...                                                  ...     ...     ...
# 14538  CN1CCN(C2=CC=C(NC3=CC(=O)N(C4=CC=C(Cl)C=C4)N=C...   0.020      uM
# 14539                     NCC1=CC=C(C2=CC=CC=C2)C(Cl)=C1     270      uM
# 14540  CC(C)[C@H](NC(=O)OCC1=CC=CC=C1)[P@](=O)(O)C[C@...      12      nM
# 14541  COC1=CC2=CC([C@@](C)(F)C3=NN=C4C(F)=CC(C5=CC(C...       2      nM
# 14542          O=C(C1=CC=C2N=CC=CC2=C1)C1=C(Cl)C=CC=C1Cl     139      uM
#
#        Unit                           Total_Lig_info
# 0      7.89                                82D_A_501
# 1      7.66                      HLM_A_401,HLM_B_401
# 2      6.24                                H3W_A_501
# 3       8.1  GRW_H_301,GRW_K_301,GRW_V_301,GRW_Y_301
# 4      8.72  15R_A_401,15R_B_401,15R_C_401,15R_D_401
# ...     ...                                      ...
# 14538   7.7                    JWF_A_2000,JWF_B_2000
# 14539  3.57  54E_A_401,54E_A_402,54E_B_403,54E_B_404
# 14540  7.92            864_A_401,864_B_501,864_C_601
# 14541   8.7                               46G_A_1401
# 14542  3.86                      5F6_A_401,5F6_B_401
#
# [14543 rows x 9 columns]

# %% [markdown]
# #### 6.2 CASF2016 dataset

# %%
CASF2016_ligand_info_results = parallelize_dataframe(CASF2016_df, extract_ligand_info_bulk, 10)

# %%
CASF2016_ligand_info_results = pd.concat(CASF2016_ligand_info_results)

# %%
CASF2016_df["Total_Lig_info"] = CASF2016_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
CASF2016_df = CASF2016_df.dropna(axis = 0).reset_index(drop=True)
CASF2016_df
# Out:
#       PDB Lig_code Labels                                   OE_stereo_SMILES  \
# 0    1bcu      PRL   3.28                         c1cc(cc2c1cc3ccc(cc3n2)N)N
# 1    1bzc      TPI   4.92  c1cc(cc2c1cc(cc2)C(F)(F)P(=O)(O)O)C(=O)N[C@@H]...
# 2    1c5z      BEN   4.01                               [H]/N=C(\c1ccccc1)/N
# 3    1e66      HUX   9.89  CCC1=C[C@@H]2Cc3c(c(c4ccc(cc4n3)Cl)N)[C@@H](C2)C1
# 4    1eby      BEB   9.70  c1ccc(cc1)CO[C@H]([C@@H]([C@H]([C@H](C(=O)N[C@...
# ..    ...      ...    ...                                                ...
# 274  5aba      UL7   2.98          c1c(cc(c(c1CN2CCC(CC2)N3CCC(CC3)O)O)Br)Cl
# 275  5c28      4XV   5.66                              Cc1c(nc(nc1Cl)C2CC2)N
# 276  5c2h      4XU  11.09   Cc1c(nc(nc1Cl)OCCCc2ccc3ccccc3n2)NCc4c(nc(s4)C)C
# 277  5dwr      5H7  11.22  C[C@H]1C[C@H](C[C@H](C1)N)c2ccncc2NC(=O)c3ccc(...
# 278  5tmn      0PJ   8.04  CC(C)C[C@@H](C(=O)N[C@@H](CC(C)C)C(=O)O)NP(=O)...
#
#                                       RDKit_iso_SMILES Measure Potency   Unit  \
# 0                    NC1=CC2=NC3=C(C=CC(N)=C3)C=C2C=C1    0.53      mM   3.28
# 1    NC(=O)[C@H](CCC(=O)O)NC(=O)C1=CC2=C(C=C1)C=C(C...      12      uM   4.92
# 2                               [H]/N=C(/N)C1=CC=CC=C1      97      uM   4.01
# 3    CCC1=C[C@@H]2CC3=C(C(N)=C4C=CC(Cl)=CC4=N3)[C@H...    0.13      nM   9.89
# 4    O=C(N[C@H]1C2=CC=CC=C2C[C@H]1O)[C@H](OCC1=CC=C...    0.20      nM    9.7
# ..                                                 ...     ...     ...    ...
# 274         OC1=C(CN2CCC(N3CCC(O)CC3)CC2)C=C(Cl)C=C1Br    1040      uM   2.98
# 275                           CC1=C(N)N=C(C2CC2)N=C1Cl     2.2      uM   5.66
# 276  CC1=NC(C)=C(CNC2=C(C)C(Cl)=NC(OCCCC3=CC=C4C=CC...     8.2      pM  11.09
# 277  C[C@@H]1C[C@H](N)C[C@H](C2=CC=NC=C2NC(=O)C2=CC...       6      pM  11.22
# 278  CC(C)C[C@H](NC(=O)[C@H](CC(C)C)NP(=O)(O)CNC(=O...     9.1      nM   8.04
#
#             Total_Lig_info
# 0                PRL_H_280
# 1                TPI_A_902
# 2                BEN_B_251
# 3                HUX_A_803
# 4                BEB_B_501
# ..                     ...
# 274  UL7_A_1291,UL7_B_1291
# 275              4XV_A_803
# 276              4XU_B_803
# 277              5H7_A_401
# 278              0PJ_E_317
#
# [279 rows x 9 columns]

# %% [markdown]
# #### 6.3 CASF2013 dataset

# %%
CASF2013_ligand_info_results = parallelize_dataframe(CASF2013_df, extract_ligand_info_bulk, 10)

# %%
CASF2013_ligand_info_results = pd.concat(CASF2013_ligand_info_results)

# %%
CASF2013_df["Total_Lig_info"] = CASF2013_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
CASF2013_df = CASF2013_df.dropna(axis = 0).reset_index(drop=True)
CASF2013_df
# Out:
#       PDB Lig_code Labels                                   OE_stereo_SMILES  \
# 0    10gs      VWW   6.40  c1ccc(cc1)CSC[C@@H](C(=O)N[C@H](c2ccccc2)C(=O)...
# 1    1bcu      PRL   3.28                         c1cc(cc2c1cc3ccc(cc3n2)N)N
# 2    1e66      HUX   9.89  CCC1=C[C@@H]2Cc3c(c(c4ccc(cc4n3)Cl)N)[C@@H](C2)C1
# 3    1f8b      DAN   5.40  CC(=O)N[C@@H]1[C@H](C=C(O[C@H]1[C@@H]([C@@H](C...
# 4    1f8c      4AM   7.40  CC(=O)N[C@@H]1[C@H](C=C(O[C@H]1[C@@H]([C@@H](C...
# ..    ...      ...    ...                                                ...
# 172  4djv      0KM   6.72  [H]/N=C/1\N[C@](C(=O)N1C)(c2ccccc2)c3cccc(c3)c...
# 173  4g8m      G8M   7.89            C1C[C@@H]([C@@H]1[C@@H](C(=O)O)N)C(=O)O
# 174  4gid      0GH  10.77  C[C@H](c1ccccc1)NC(=O)c2cc(cc(c2)N(C)S(=O)(=O)...
# 175  4gqq      0XR   2.89                        CCOC(=O)/C=C/c1ccc(c(c1)O)O
# 176  4tmn      0PK  10.17  C[C@@H](C(=O)O)NC(=O)[C@H](CC(C)C)NP(=O)([C@H]...
#
#                                       RDKit_iso_SMILES Measure Potency   Unit  \
# 0    N[C@@H](CCC(=O)N[C@@H](CSCC1=CC=CC=C1)C(=O)N[C...     0.4      uM    6.4
# 1                    NC1=CC2=NC3=C(C=CC(N)=C3)C=C2C=C1    0.53      mM   3.28
# 2    CCC1=C[C@@H]2CC3=C(C(N)=C4C=CC(Cl)=CC4=N3)[C@H...    0.13      nM   9.89
# 3    CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)OC(C(=O)...     4.0      uM    5.4
# 4    CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)OC(C(=O)...    0.04      uM    7.4
# ..                                                 ...     ...     ...    ...
# 172  [H]/N=C1\N[C@](C2=CC=CC=C2)(C2=CC=CC(C3=CC=CC(...    0.19      uM   6.72
# 173               N[C@H](C(=O)O)[C@@H]1CC[C@@H]1C(=O)O    12.8      nM   7.89
# 174  CC(C)CNC(=O)[C@@H](NC[C@H](CC1=CC=CC=C1)NC(=O)...   0.017      nM  10.77
# 175                     CCOC(=O)/C=C/C1=CC=C(O)C(O)=C1     1.3      mM   2.89
# 176  CC(C)C[C@H](NP(=O)(O)[C@H](CC1=CC=CC=C1)NC(=O)...   0.068      nM  10.17
#
#                               Total_Lig_info
# 0                        VWW_A_210,VWW_B_210
# 1                                  PRL_H_280
# 2                                  HUX_A_803
# 3                                    DAN_A_0
# 4                                    4AM_A_4
# ..                                       ...
# 172                      0KM_A_501,0KM_B_501
# 173                      G8M_A_301,G8M_B_901
# 174  0GH_A_501,0GH_B_501,0GH_C_501,0GH_D_501
# 175            0XR_A_502,0XR_A_503,0XR_A_504
# 176                                0PK_E_317
#
# [177 rows x 9 columns]

# %% [markdown]
# #### 6.4 CSAR2014 dataset

# %%
CSAR2014_ligand_info_results = parallelize_dataframe(CSAR2014_df, extract_ligand_info_bulk, 10)

# %%
CSAR2014_ligand_info_results = pd.concat(CSAR2014_ligand_info_results)

# %%
CSAR2014_df["Total_Lig_info"] = CSAR2014_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
CSAR2014_df = CSAR2014_df.dropna(axis = 0).reset_index(drop=True)
CSAR2014_df
# Out:
#      PDB Lig_code  Labels                                   OE_stereo_SMILES  \
# 0   4ypw      4FD    5.50                       c1ccc(cc1)CNc2ccc(cn2)C(=O)N
# 1   4ypx      4FG    4.60                                  c1cc(ncc1C(=O)N)N
# 2   4ypy      4F9    3.80                                 c1cnccc1c2cnc[nH]2
# 3   4ypz      4FL    3.50                                 c1cnccc1c2[nH]ccn2
# 4   4yq0      4FM    4.40                      c1cc(ccc1CNC(=O)c2c(non2)N)Cl
# 5   4yq1      4FN    8.30  CC(C)(C)c1cccc(c1)C(=O)NCC2(CCCCC2)NC(=O)c3ccc...
# 6   4yq2      EFY    8.30  CC(C)(C)c1cccc(c1)C(=O)NCC2(CCCC2)NC(=O)c3cccc...
# 7   4yq3      4G1    6.80     Cc1cccc(c1)C(=O)NCC2(CCCC2)NC(=O)c3cccc4c3con4
# 8   4yq4      4G3    5.70                    c1cc(cc(c1)O)CNc2ccc(cn2)C(=O)N
# 9   4yq5      4G0    5.40                  CN(C)c1cccc(c1)CNc2ccc(cn2)C(=O)N
# 10  4yq6      4FX    6.10                       COc1ccccc1CNc2ccc(cn2)C(=O)N
# 11  4yq7      4G4    5.20                    CN(C)c1ccccc1CNc2ccc(cn2)C(=O)N
# 12  4yq8      4FV    5.10               C1C[C@@H](C[C@@H]1NC(=O)c2c(non2)N)O
# 13  4yq9      4GO    6.70                           c1cc(ncc1C(=O)N)NC2CCCC2
# 14  4yqa      4GN    6.30                          c1cc(ncc1C(=O)N)NCC2CCCC2
# 15  4yqb      4GM    5.90                    c1ccc(c(c1)CNc2ccc(cn2)C(=O)N)O
# 16  4yqc      EFW    6.70               c1cc(ncc1C(=O)N)N[C@@H]2CC[C@H](C2)O
# 17  4yqd      4GZ    5.10    Cc1cccc(c1)C(=O)NCCC2(CCCCC2)CNc3ccc(cn3)C(=O)N
# 18  4yqg      4GY    5.70                        C1CCC(CC1)CNC(=O)c2c(non2)N
# 19  4yqi      4GX    4.80               c1ccnc(c1)CN2CCN(CC2)C(=O)c3c(non3)N
# 20  4yqj      4GT    6.20                      c1c(c(nc(n1)NC2CCCC2)N)C(=O)N
# 21  4yqk      4GS    4.70                           C1CNCCC1NC(=O)c2c(non2)N
# 22  4yql      4H4    4.80  c1cc(ccc1[C@H]2C[C@@H]2NC(=O)c3c(non3)N)S(=O)(...
# 23  4yqn      4H3    5.80      c1cc(ncc1C(=O)N)N[C@@H]2C[C@@H]([C@H](C2)O)CO
# 24  4yqo      4H1    6.30           c1cc(ncc1C(=O)N)NC[C@@H]2CCC[C@@H](C2)CN
# 25  4yqp      4H6    5.70             c1ccc(c(c1)CNc2ccc(cn2)C(=O)N)N3CCOCC3
# 26  4yqq      4H7    6.10              CN1CCN(CC1)c2ccccc2CNc3ccc(cn3)C(=O)N
# 27  4yqr      4HQ    4.00                         CN1CCN(CC1)C(=O)c2c(non2)N
# 28  4yqs      4H9    5.60                        COc1ccc(cc1)C(=O)n2c(ncn2)N
# 29  4yqt      4H8    6.10                      CC(C)(C)CNc1ncc(c(n1)N)C(=O)N
# 30  4yjo      4DF    7.90  CCN(c1cccc2c1cn[nH]2)c3c(cnc(n3)Nc4ccc5c(c4)S(...
# 31  4yjp      4DL    8.46  c1cc2c(cn[nH]2)c(c1)N(CCO)c3ccnc(n3)Nc4ccc5c(c...
# 32  4yjq      4DK    7.95  Cc1c(ocn1)c2cccc(c2)Nc3nccc(n3)N(CCCO)c4cccc5c...
# 33  4yjr      4DJ    7.69  Cn1c2ccc(cc2cn1)Nc3nccc(n3)N(CCCO)c4cccc5c4cn[...
# 34  4yjs      4DN    9.39  c1cc2c(cn[nH]2)c(c1)N(CCCO)c3ccnc(n3)Nc4ccc5c(...
# 35  4yjt      4DQ    8.79  CCN(c1cccc2c1cn[nH]2)c3c(cnc(n3)Nc4ccc5c(c4)S(...
# 36  4yju      4DO    7.94  CN(c1cccc2c1cn[nH]2)c3c(cnc(n3)Nc4ccc5c(c4)S(=...
# 37  4yjv      4DT    8.55  CCN(c1cccc2c1cn[nH]2)c3c(cnc(n3)NC4=CCC5=CNN(C...
# 38  4ykr      4EP    7.53                   CCCc1cc(c(cc1O)O)N2c3ccccc3NC2=O
# 39  4ykq      4EO    7.61                    CCc1cc(c(cc1O)O)N2c3ccccc3NC2=O
# 40  4ykt      4EQ    8.28  c1cc(cnc1)S(NCc2ccc3c(c2)NC(=O)N3c4cc(c(cc4O)O...
# 41  4ykw      4ES    7.02             Cc1cc(nc(n1)N)c2ccc(cc2Cl)[N+](=O)[O-]
# 42  4ykx      4ET    5.56                      c1cc(ccc1C(=O)c2cc(ccc2O)Cl)O
# 43  4ykz      4EV    5.06                     c1cc(cc(c1)O)C(=O)c2ccc(cc2O)O
# 44  4yky      4EU    4.30                       c1cc(ccc1C(=O)c2ccc(cc2O)O)O
# 45  4yku      4ER    5.12                       c1ccc(c(c1)c2nc(nc(n2)N)N)Cl
#
#                                      RDKit_iso_SMILES Measure     Potency  \
# 0                    NC(=O)C1=CC=C(NCC2=CC=CC=C2)N=C1    IC50    3162.000
# 1                                NC(=O)C1=CN=C(N)C=C1    IC50   25119.000
# 2                              C1=CC(C2=CN=CN2)=CC=N1    IC50  158489.000
# 3                              C1=CC(C2=NC=CN2)=CC=N1    IC50  316228.000
# 4                    NC1=NON=C1C(=O)NCC1=CC=C(Cl)C=C1    IC50   39811.000
# 5   CC(C)(C)C1=CC=CC(C(=O)NCC2(NC(=O)C3=CC=CC4=NOC...    IC50       5.010
# 6   CC(C)(C)C1=CC=CC(C(=O)NCC2(NC(=O)C3=CC=CC4=NOC...    IC50       5.010
# 7   CC1=CC=CC(C(=O)NCC2(NC(=O)C3=CC=CC4=NOC=C34)CC...    IC50     158.000
# 8                 NC(=O)C1=CC=C(NCC2=CC(O)=CC=C2)N=C1    IC50    1995.000
# 9             CN(C)C1=CC=CC(CNC2=CC=C(C(N)=O)C=N2)=C1    IC50    3981.000
# 10                 COC1=CC=CC=C1CNC1=CC=C(C(N)=O)C=N1    IC50     794.000
# 11              CN(C)C1=CC=CC=C1CNC1=CC=C(C(N)=O)C=N1    IC50    6310.000
# 12                NC1=NON=C1C(=O)N[C@@H]1CC[C@H](O)C1    IC50    7943.000
# 13                        NC(=O)C1=CN=C(NC2CCCC2)C=C1    IC50     200.000
# 14                       NC(=O)C1=CN=C(NCC2CCCC2)C=C1    IC50     501.000
# 15                  NC(=O)C1=CC=C(NCC2=CC=CC=C2O)N=C1    IC50    1259.000
# 16           NC(=O)C1=CN=C(N[C@@H]2CC[C@@H](O)C2)C=C1    IC50     200.000
# 17  CC1=CC=CC(C(=O)NCCC2(CNC3=CC=C(C(N)=O)C=N3)CCC...    IC50    7943.000
# 18                          NC1=NON=C1C(=O)NCC1CCCCC1    IC50    1995.000
# 19              NC1=NON=C1C(=O)N1CCN(CC2=CC=CC=N2)CC1    IC50   15849.000
# 20                       NC(=O)C1=CN=C(NC2CCCC2)N=C1N    IC50     631.000
# 21                           NC1=NON=C1C(=O)NC1CCNCC1    IC50   19953.000
# 22  NC1=NON=C1C(=O)N[C@H]1C[C@@H]1C1=CC=C(S(N)(=O)...    IC50   15849.000
# 23   NC(=O)C1=CN=C(N[C@@H]2C[C@H](CO)[C@@H](O)C2)C=C1    IC50    1585.000
# 24         NC[C@H]1CCC[C@@H](CNC2=NC=C(C(N)=O)C=C2)C1    IC50     501.000
# 25           NC(=O)C1=CC=C(NCC2=CC=CC=C2N2CCOCC2)N=C1    IC50    1995.000
# 26        CN1CCN(C2=CC=CC=C2CNC2=CC=C(C(N)=O)C=N2)CC1    IC50     794.000
# 27                         CN1CCN(C(=O)C2=NON=C2N)CC1    IC50  100000.000
# 28                     COC1=CC=C(C(=O)N2N=CN=C2N)C=C1    IC50    2512.000
# 29                   CC(C)(C)CNC1=NC=C(C(N)=O)C(N)=N1    IC50     794.000
# 30  CCN(C1=C(Cl)C=NC(NC2=CC=C3CNS(=O)(=O)C3=C2)=N1...    IC50      12.700
# 31  O=S1(=O)NCC2=CC=C(NC3=NC(N(CCO)C4=CC=CC5=C4C=N...    IC50       3.450
# 32  CC1=C(C2=CC=CC(NC3=NC=CC(N(CCCO)C4=CC=CC5=C4C=...    IC50      11.100
# 33  CN1N=CC2=CC(NC3=NC=CC(N(CCCO)C4=CC=CC5=C4C=NN5...    IC50      20.600
# 34  O=S1(=O)NCC2=CC=C(NC3=NC(N(CCCO)C4=CC=CC5=C4C=...    IC50       0.412
# 35  CCN(C1=C(F)C=NC(NC2=CC=C3CNS(=O)(=O)C3=C2)=N1)...    IC50       1.610
# 36  CN(C1=C(F)C=NC(NC2=CC=C3CNS(=O)(=O)C3=C2)=N1)C...    IC50      11.600
# 37  CCN(C1=C(F)C=NC(NC2=CCC3=CNN(CCCO)C3=C2)=N1)C1...    IC50       2.810
# 38           CCCC1=CC(N2C(=O)NC3=CC=CC=C32)=C(O)C=C1O    IC50      29.200
# 39            CCC1=CC(N2C(=O)NC3=CC=CC=C32)=C(O)C=C1O    IC50      24.800
# 40  O=C1NC2=CC(CNS(O)(O)C3=CN=CC=C3)=CC=C2N1C1=CC(...    IC50       5.220
# 41       CC1=CC(C2=CC=C([N+](=O)[O-])C=C2Cl)=NC(N)=N1    IC50      96.100
# 42                O=C(C1=CC=C(O)C=C1)C1=CC(Cl)=CC=C1O    IC50    2770.000
# 43                 O=C(C1=CC(O)=CC=C1)C1=CC=C(O)C=C1O    IC50    8680.000
# 44                 O=C(C1=CC=C(O)C=C1)C1=CC=C(O)C=C1O    IC50   50000.000
# 45                     NC1=NC(C2=CC=CC=C2Cl)=NC(N)=N1    IC50    7590.000
#
#    Unit       Total_Lig_info
# 0    nM            4FD_A_301
# 1    nM            4FG_A_301
# 2    nM            4F9_A_301
# 3    nM            4FL_A_301
# 4    nM            4FM_A_301
# 5    nM            4FN_A_301
# 6    nM            EFY_A_301
# 7    nM            4G1_A_301
# 8    nM            4G3_A_301
# 9    nM            4G0_A_301
# 10   nM            4FX_A_301
# 11   nM            4G4_A_301
# 12   nM            4FV_A_301
# 13   nM            4GO_A_301
# 14   nM            4GN_A_301
# 15   nM            4GM_A_301
# 16   nM            EFW_A_301
# 17   nM            4GZ_A_301
# 18   nM            4GY_A_301
# 19   nM            4GX_A_301
# 20   nM            4GT_A_301
# 21   nM            4GS_A_301
# 22   nM            4H4_A_301
# 23   nM            4H3_A_301
# 24   nM            4H1_A_301
# 25   nM            4H6_A_301
# 26   nM            4H7_A_301
# 27   nM            4HQ_A_301
# 28   nM            4H9_A_301
# 29   nM            4H8_A_301
# 30   nM            4DF_A_701
# 31   nM            4DL_A_701
# 32   nM            4DK_A_701
# 33   nM            4DJ_A_701
# 34   nM            4DN_A_701
# 35   nM            4DQ_A_702
# 36   nM            4DO_A_701
# 37   nM            4DT_A_701
# 38   nM            4EP_A_301
# 39   nM            4EO_A_301
# 40   nM            4EQ_A_301
# 41   nM  4ES_A_301,4ES_B_301
# 42   nM            4ET_A_301
# 43   nM            4EV_A_301
# 44   nM            4EU_A_301
# 45   nM            4ER_A_301

# %% [markdown]
# #### 6.5 CSAR2012 dataset

# %%
CSAR2012_ligand_info_results = parallelize_dataframe(CSAR2012_df, extract_ligand_info_bulk, 10)

# %%
CSAR2012_ligand_info_results = pd.concat(CSAR2012_ligand_info_results)

# %%
CSAR2012_df["Total_Lig_info"] = CSAR2012_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
CSAR2012_df = CSAR2012_df.dropna(axis = 0).reset_index(drop=True)
CSAR2012_df
# Out:
#      PDB Lig_code  Labels                                   OE_stereo_SMILES  \
# 0   4fud      6UP    6.35                      [H]/N=C(\c1ccc2cccc(c2c1)N)/N
# 1   4fue      7UP    7.23    [H]/N=C(/c1ccc2cc(ccc2c1)C#Cc3ccc4c(c3)CCNC4)\N
# 2   4fu7      1UP    6.20           [H]/N=C(/c1ccc2ccc(c(c2c1)OCC(=O)N)OC)\N
# 3   4fu8      2UP    5.23                         [H]/N=C(\c1ccc2ccccc2c1)/N
# 4   4fu9      675    6.20         [H]/N=C(/c1ccc2cc(ccc2c1)C(=O)Nc3ccccc3)\N
# 5   4fub      4UP    6.21  [H]/N=C(/c1ccc2cc(ccc2c1)[C@H]3[C@@H](O3)c4ccc...
# 6   4fuc      239    7.40     [H]/N=C(/c1ccc2cc(ccc2c1)C(=O)Nc3ccc(cc3)CN)\N
# 7   4fsm      HK1    7.62        COc1cc2c(cc1OC)-c3c(c([nH]n3)c4ccc(cc4)O)C2
# 8   4fsw      HK6    4.76                    c1ccc2c(c1)C(=O)Nc3cc(ccc3N2)Cl
# 9   4ft5      H2K    7.56    c1cc(c(cc1Cl)NC(=O)Nc2cnc(cn2)C#N)O[C@@H]3CCNC3
# 10  4fsn      A58    7.70  CC1CCC(CC1)NCc2ccc-3c(c2)Cc4c3[nH]nc4c5ccc(cc5...
# 11  4fsz      HK8    6.97             c1cc2c(cc1CC(=O)O)NC(=O)c3ccc(cc3N2)Cl
# 12  4ft7      H3K    8.87  c1cc(c(cc1Br)NC(=O)Nc2cnc(cn2)C#N)N3CCC[C@H](C3)O
# 13  4ft0      HK9    7.11        COc1cc(ccc1C(=O)O)c2ccc3c(c2)Nc4ccccc4NC3=O
# 14  4ft9      H4K    7.69               c1ccc2cnc(cc2c1)NC(=O)Nc3cnc(cn3)C#N
# 15  4fta      H5K    7.39       c1cc(cc2c1cc(cc2)NC(=O)Nc3cnc(cn3)C#N)C(=O)O
# 16  4ftc      H6K    7.63         c1ccc(cc1)c2cc(n[nH]2)NC(=O)Nc3cnc(cn3)C#N
# 17  4fsq      HK3    8.80  COC1=CC2=CC3=C(N=NC3=C2C=C1OC)c4ccc(cc4)c5ccc(...
# 18  4fsr      HKC    7.94  COc1cc2c(cc1OC)-c3c(c(n[nH]3)c4ccc(cc4)c5[nH]n...
# 19  4fst      HK4    8.28   COc1cc(ccc1O)C#Cc2c3c(n[nH]2)-c4cc(c(cc4C3)OC)OC
# 20  4fw3      L52    7.23  c1ccc(cc1)C#CC#Cc2ccc(cc2)C(=O)N[C@@H](CN)C(=O)NO
# 21  4fw4      3P3    8.08  C[C@H]([C@@H](C(=O)NO)NC(=O)c1ccc(cc1)C#CC#Cc2...
# 22  4fw5      L58    7.48  C[C@H]([C@@H](C(=O)NO)NC(=O)c1ccc(cc1)c2ccc(cc...
# 23  4fw6      L59    7.70  C[C@H]([C@@H](C(=O)NO)NC(=O)c1ccc(cc1)C#Cc2ccc...
# 24  4fw7      L63    7.13   C[C@H]([C@@H](C(=O)NO)NC(=O)c1ccc(cc1)c2ccccc2)O
# 25  4fux      E75    6.00         Cc1c(c(no1)c2ccccc2)c3ccnc(n3)NC4CCC(CC4)O
# 26  4fuy      EK2    6.09  c1c(cc(cc1Cl)Cl)c2cn[nH]c2c3cc([nH]c3)C(=O)N4C...
# 27  4fv0      EK3    5.59         c1cc(ccc1c2c(c[nH]n2)c3ccnc(c3)NC4CCCCC4)F
# 28  4fv1      EK4    7.08  c1ccc(cc1)[C@@H](CO)NC(=O)c2cc(c[nH]2)c3c(cn[n...
# 29  4fv2      EK5    7.68  c1cc(cc(c1)Cl)c2cn[nH]c2c3cc([nH]c3)C(=O)NCc4c...
# 30  4fv3      EK6    7.74  CCOC(=O)CNCc1ccc(cc1Cl)c2cn[nH]c2c3cc([nH]c3)C...
# 31  4ev4      MER    7.40  C[C@@H]1[C@@H](NC(=C1S[C@H]2C[C@H](NC2)C(=O)N(...
# 32  4fv5      EK9    7.70  Cc1cnc(nc1c2cc([nH]c2)C(=O)N[C@H](CO)c3ccccc3)...
# 33  4fv7      E94    7.57  c1cc(cc(c1)Cl)c2c(c(sc2c3ccnc(n3)Nc4cccc(c4)O)...
# 34  4fv8      E63    7.82  c1ccc(cc1)Nc2cnc(nc2Nc3cc(n[nH]3)C4CC4)Nc5ccc6...
# 35  4fv9      E71    6.72  c1cc(c(c(c1)F)F)c2cnoc2c3c[nH]c4c3cc(cn4)c5ccncc5
# 36  4fx3      60K    8.07  c1cc(ccc1N/N=C\2/c3cc(ccc3NC2=O)C(=O)O)S(=O)(=O)N
# 37  4ek4      1CK    4.48                    Cc1cc(n[nH]1)NC(=O)c2ccc(cc2)Br
# 38  4ek5      03K    6.09            c1cc(ccc1C(=O)N)C(=O)Nc2cc([nH]n2)C3CC3
# 39  4fkg      4CK    4.67            c1cc(ccc1C(=O)Nc2cc([nH]n2)C3CC3)C(=O)O
# 40  4fki      09K    4.23        c1cc(ccc1CC(=O)Nc2cc(n[nH]2)C3CC3)OC(F)(F)F
# 41  4ek6      10K    6.04        c1cc(sc1)c2ccc(cc2)CC(=O)Nc3cc(n[nH]3)C4CC4
# 42  4fjk      DTP    6.55  c1nc(c2c(n1)n(cn2)[C@H]3C[C@@H]([C@H](O3)CO[P@...
# 43  4ek8      16K    7.11     Cc1c(sc(n1)C)c2ccnc(n2)Nc3cccc(c3)[N+](=O)[O-]
# 44  3sw4      18K    6.02            Cc1c(sc(n1)N)c2ccnc(n2)Nc3ccc(cc3)N(C)C
# 45  3sw7      19K    6.64  Cc1c(sc(n1)C)c2ccnc(n2)Nc3ccc(c(c3)[N+](=O)[O-...
# 46  4fko      20K    6.11        Cc1c(sc(n1)C)c2ccnc(n2)Nc3ccc(c(c3)Cl)N(C)C
# 47  4fkp      LS5    6.54  c1ccc2c(c1)/C(=C/Nc3ccc(cc3)S(=O)(=O)NC(=N)N)/...
# 48  4fkq      42K    6.28  c1cc(ccc1N/N=C\2/c3c(ccc4c3nn[nH]4)NC2=O)S(=O)...
# 49  4fkr      45K    6.64  c1cc2c(cc1N/C=C\3/c4c(ccc5c4scn5)NC3=O)CS(=O)(...
# 50  4fks      46K    6.28  CC(=O)NS(=O)(=O)c1ccc(cc1)N/C=C\2/c3c(ccc4c3sc...
# 51  4fkt      48K    5.97   CN(C)CCNS(=O)(=O)c1ccc(cc1)N/C=C\2/c3ccccc3NC2=O
# 52  4fku      60K    7.01  c1cc(ccc1N/N=C\2/c3cc(ccc3NC2=O)C(=O)O)S(=O)(=O)N
# 53  4fkv      61K    6.60  c1cc(ccc1N/N=C\2/c3cc(ccc3NC2=O)C(=O)NCCc4c[nH...
# 54  4fkw      62K    7.33  CC(C)COC(=O)c1ccc2c(c1)/C(=N/Nc3ccc(cc3)S(=O)(...
#
#                                      RDKit_iso_SMILES Measure   Potency Unit  \
# 0                   [H]/N=C(/N)C1=CC=C2C=CC=C(N)C2=C1      Ki    450.00   nM
# 1   [H]/N=C(\N)C1=CC=C2C=C(C#CC3=CC=C4CNCCC4=C3)C=...      Ki     58.80   nM
# 2        [H]/N=C(\N)C1=CC=C2C=CC(OC)=C(OCC(N)=O)C2=C1      Ki    637.00   nM
# 3                      [H]/N=C(/N)C1=CC=C2C=CC=CC2=C1      Ki   5910.00   nM
# 4   [H]/N=C(\N)C1=CC=C2C=C(C(=O)NC3=CC=CC=C3)C=CC2=C1      Ki    628.00   nM
# 5   [H]/N=C(\N)C1=CC=C2C=C([C@@H]3O[C@H]3C3=CC=CC=...      Ki    610.00   nM
# 6   [H]/N=C(\N)C1=CC=C2C=C(C(=O)NC3=CC=C(CN)C=C3)C...      Ki     40.00   nM
# 7       COC1=CC2=C(C=C1OC)C1=NNC(C3=CC=C(O)C=C3)=C1C2    IC50     23.90   nM
# 8                   O=C1NC2=CC(Cl)=CC=C2NC2=CC=CC=C12    IC50  17200.00   nM
# 9   N#CC1=NC=C(NC(=O)NC2=C(O[C@@H]3CCNC3)C=CC(Cl)=...    IC50     27.40   nM
# 10  CC1CCC(NCC2=CC=C3C(=C2)CC2=C3NN=C2C2=CC=C(C(=O...    IC50     19.90   nM
# 11       O=C(O)CC1=CC2=C(C=C1)NC1=CC(Cl)=CC=C1C(=O)N2    IC50    106.00   nM
# 12  N#CC1=NC=C(NC(=O)NC2=C(N3CCC[C@@H](O)C3)C=CC(B...    IC50      1.36   nM
# 13  COC1=CC(C2=CC=C3C(=O)NC4=CC=CC=C4NC3=C2)=CC=C1...    IC50     76.80   nM
# 14         N#CC1=NC=C(NC(=O)NC2=CC3=CC=CC=C3C=N2)N=C1    IC50     20.60   nM
# 15  N#CC1=NC=C(NC(=O)NC2=CC3=C(C=C2)C=C(C(=O)O)C=C...    IC50     40.40   nM
# 16      N#CC1=NC=C(NC(=O)NC2=NNC(C3=CC=CC=C3)=C2)N=C1    IC50     23.20   nM
# 17  COC1=CC2=CC3=C(C4=CC=C(C5=CC=C(O)C=C5)C=C4)N=N...    IC50      1.60   nM
# 18  COC1=CC2=C(C=C1OC)C1=C(C2)C(C2=CC=C(C3=NN=NN3)...    IC50     11.50   nM
# 19  COC1=CC(C#CC2=C3CC4=CC(OC)=C(OC)C=C4C3=NN2)=CC...    IC50      5.22   nM
# 20  NC[C@H](NC(=O)C1=CC=C(C#CC#CC2=CC=CC=C2)C=C1)C...      Kd     58.60   nM
# 21  C[C@@H](O)[C@H](NC(=O)C1=CC=C(C#CC#CC2=CC=CC=C...      Kd      8.35   nM
# 22  C[C@@H](O)[C@H](NC(=O)C1=CC=C(C2=CC=C(Br)C=C2)...      Kd     33.20   nM
# 23  C[C@@H](O)[C@H](NC(=O)C1=CC=C(C#CC2=CC=CC=C2)C...      Kd     20.10   nM
# 24  C[C@@H](O)[C@H](NC(=O)C1=CC=C(C2=CC=CC=C2)C=C1...      Kd     74.50   nM
# 25  CC1=C(C2=CC=NC(NC3CCC(O)CC3)=N2)C(C2=CC=CC=C2)...      Ki   1000.00   nM
# 26  O=C(C1=CC(C2=C(C3=CC(Cl)=CC(Cl)=C3)C=NN2)=CN1)...      Ki    812.80   nM
# 27      FC1=CC=C(C2=NNC=C2C2=CC=NC(NC3CCCCC3)=C2)C=C1      Ki   2570.40   nM
# 28  O=C(N[C@H](CO)C1=CC=CC=C1)C1=CC(C2=C(C3=CC=CC(...      Ki     83.20   nM
# 29  O=C(NCC1=CC=C2OCCC2=C1)C1=CC(C2=C(C3=CC(Cl)=CC...      Ki     20.90   nM
# 30  CCOC(=O)CNCC1=CC=C(C2=C(C3=CNC(C(=O)N[C@H](CO)...      Ki     18.20   nM
# 31  C[C@@H](O)[C@@H](C=O)[C@@H]1NC(C(=O)O)=C(S[C@@...      Ki     39.80   nM
# 32  CC1=CN=C(C2=CC=CC=C2)N=C1C1=CNC(C(=O)N[C@H](CO...      Ki     20.00   nM
# 33  N#CC1=C(NCCN2CCCCC2)SC(C2=CC=NC(NC3=CC=CC(O)=C...      Ki     26.90   nM
# 34  O=C1NNC2=CC(NC3=NC=C(NC4=CC=CC=C4)C(NC4=CC(C5C...      Ki     15.10   nM
# 35  FC1=CC=CC(C2=C(C3=CNC4=C3C=C(C3=CC=NC=C3)C=N4)...      Ki    190.50   nM
# 36  NS(=O)(=O)C1=CC=C(N/N=C2\C(=O)NC3=CC=C(C(=O)O)...      Kd      8.43   nM
# 37                  CC1=CC(NC(=O)C2=CC=C(Br)C=C2)=NN1      Kd  33200.00   nM
# 38          NC(=O)C1=CC=C(C(=O)NC2=NNC(C3CC3)=C2)C=C1      Kd    808.00   nM
# 39          O=C(O)C1=CC=C(C(=O)NC2=NNC(C3CC3)=C2)C=C1      Kd  21200.00   nM
# 40      O=C(CC1=CC=C(OC(F)(F)F)C=C1)NC1=CC(C2CC2)=NN1      Kd  58300.00   nM
# 41      O=C(CC1=CC=C(C2=CC=CS2)C=C1)NC1=CC(C2CC2)=NN1      Kd    910.00   nM
# 42  NC1=C2N=CN([C@H]3C[C@H](O)[C@@H](CO[P@](=O)(O)...      Kd    280.00   nM
# 43  CC1=NC(C)=C(C2=CC=NC(NC3=CC=CC([N+](=O)[O-])=C...      Kd     77.30   nM
# 44    CC1=C(C2=CC=NC(NC3=CC=C(N(C)C)C=C3)=N2)SC(N)=N1      Kd    961.00   nM
# 45  CC1=NC(C)=C(C2=CC=NC(NC3=CC=C(N(C)C)C([N+](=O)...      Kd    229.00   nM
# 46  CC1=NC(C)=C(C2=CC=NC(NC3=CC=C(N(C)C)C(Cl)=C3)=...      Kd    777.00   nM
# 47  N=C(N)NS(=O)(=O)C1=CC=C(N/C=C2\C(=O)NC3=CC=CC=...      Kd    287.00   nM
# 48  NS(=O)(=O)C1=CC=C(N/N=C2\C(=O)NC3=CC=C4NN=NC4=...      Kd    528.00   nM
# 49  O=C1NC2=CC=C3N=CSC3=C2/C1=C/NC1=CC2=C(C=C1)CS(...      Kd    229.00   nM
# 50  CC(=O)NS(=O)(=O)C1=CC=C(N/C=C2\C(=O)NC3=CC=C4N...      Kd    526.00   nM
# 51  CN(C)CCNS(=O)(=O)C1=CC=C(N/C=C2\C(=O)NC3=CC=CC...      Kd   1060.00   nM
# 52  NS(=O)(=O)C1=CC=C(N/N=C2\C(=O)NC3=CC=C(C(=O)O)...      Kd     98.60   nM
# 53  NS(=O)(=O)C1=CC=C(N/N=C2\C(=O)NC3=CC=C(C(=O)NC...      Kd    251.00   nM
# 54  CC(C)COC(=O)C1=CC=C2NC(=O)/C(=N\NC3=CC=C(S(N)(...      Kd     47.30   nM
#
#                              Total_Lig_info
# 0                                 6UP_A_301
# 1                                 7UP_A_301
# 2                                 1UP_A_305
# 3                                 2UP_A_301
# 4                                 675_A_313
# 5                                 4UP_A_301
# 6                                 239_A_301
# 7                                 HK1_A_301
# 8                                 HK6_A_301
# 9                                 H2K_A_300
# 10                                A58_A_301
# 11                                HK8_A_301
# 12                                H3K_A_301
# 13                                HK9_A_301
# 14                                H4K_A_300
# 15                                H5K_A_301
# 16                                H6K_A_301
# 17                                HK3_A_300
# 18                                HKC_A_300
# 19                                HK4_A_301
# 20  L52_A_302,L52_B_301,L52_C_301,L52_D_302
# 21  3P3_A_301,3P3_B_302,3P3_C_302,3P3_D_302
# 22  L58_A_302,L58_B_302,L58_C_302,L58_D_302
# 23  L59_A_302,L59_B_302,L59_C_302,L59_D_302
# 24  L63_A_302,L63_B_403,L63_C_302,L63_D_302
# 25                                E75_A_401
# 26                                EK2_A_401
# 27                                EK3_A_401
# 28                                EK4_A_401
# 29                                EK5_A_401
# 30                                EK6_A_401
# 31                                MER_A_401
# 32                                EK9_A_401
# 33                                E94_A_401
# 34                                E63_A_401
# 35                                E71_A_401
# 36                      60K_A_301,60K_C_301
# 37                                1CK_A_301
# 38                                03K_A_300
# 39                                4CK_A_300
# 40                                09K_A_301
# 41                                10K_A_301
# 42                               DTP_A_1001
# 43                                16K_A_301
# 44                                18K_A_299
# 45                                19K_A_299
# 46                                20K_A_301
# 47                                LS5_A_301
# 48                                42K_A_301
# 49                                45K_A_301
# 50                                46K_A_301
# 51                                48K_A_301
# 52                      60K_A_301,60K_A_303
# 53                                61K_A_301
# 54                                62K_A_301

# %% [markdown]
# #### 6.6 CSARset1 dataset

# %%
CSARset1_ligand_info_results = parallelize_dataframe(CSARset1_df, extract_ligand_info_bulk, 10)

# %%
CSARset1_ligand_info_results = pd.concat(CSARset1_ligand_info_results)

# %%
CSARset1_df["Total_Lig_info"] = CSARset1_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
CSARset1_df = CSARset1_df.dropna(axis = 0).reset_index(drop=True)
CSARset1_df
# Out:
#       PDB Lig_code Labels                                   OE_stereo_SMILES  \
# 0    2are      MAN   3.28    C([C@@H]1[C@H]([C@@H]([C@@H]([C@H](O1)O)O)O)O)O
# 1    2oag      DLI   8.47  CS(=O)(=O)c1cccc(c1)c2cc(ncn2)N3C[C@@H]([C@H](...
# 2    2jbj      G88    9.7                  C(CC(=O)O)[C@H](CP(=O)(O)O)C(=O)O
# 3    2pwd      NOJ    4.4            C1[C@@H]([C@H]([C@@H]([C@H](N1)CO)O)O)O
# 4    2pwg      CTS   4.82   C1C[N@]2C[C@@H]([C@H]([C@@H]([C@H]2[C@H]1O)O)O)O
# ..    ...      ...    ...                                                ...
# 151  3ekr      PY9   5.55              Cc1ccccc1[C@H]2CCCN2C(=O)c3ccc(cc3O)O
# 152  3ene      NPZ   6.24                Cn1c2c(c(n1)c3ccc4ccccc4c3)c(ncn2)N
# 153  3eqr      T74    8.7  Cc1cccc(c1Nc2c3cnc(nc3n(n2)CCC(C)(C)OC)Nc4ccc(...
# 154  3f8c      HT1   7.68  CCOc1ccc(cc1)c2[nH]c3cc(ccc3n2)c4[nH]c5cc(ccc5...
# 155  3fat      AMQ   7.64                      Cc1c(c(no1)O)C[C@@H](C(=O)O)N
#
#                                       RDKit_iso_SMILES  \
# 0          OC[C@H]1O[C@H](O)[C@@H](O)[C@@H](O)[C@@H]1O
# 1    CS(=O)(=O)C1=CC=CC(C2=CC(N3C[C@H](C4=CC(F)=C(F...
# 2                      O=C(O)CC[C@H](CP(=O)(O)O)C(=O)O
# 3                  OC[C@H]1NC[C@H](O)[C@@H](O)[C@@H]1O
# 4         O[C@H]1[C@H](O)[C@@H](O)CN2CC[C@H](O)[C@H]12
# ..                                                 ...
# 151        CC1=CC=CC=C1[C@H]1CCCN1C(=O)C1=CC=C(O)C=C1O
# 152           CN1N=C(C2=CC=C3C=CC=CC3=C2)C2=C1N=CN=C2N
# 153  COC(C)(C)CCN1N=C(NC2=C(C)C=CC=C2C)C2=CN=C(NC3=...
# 154  CCOC1=CC=C(C2=NC3=CC=C(C4=NC5=CC=C(N6CCN(C)CC6...
# 155                     CC1=C(C[C@H](N)C(=O)O)C(O)=NO1
#
#                     Total_Lig_info
# 0              MAN_A_253,MAN_B_253
# 1                       DLI_B_4000
# 2                       G88_A_1768
# 3            NOJ_A_8000,NOJ_B_8001
# 4            CTS_A_8000,CTS_B_8001
# ..                             ...
# 151            PY9_A_901,PY9_B_901
# 152                        NPZ_A_1
# 153                T74_A_1,T74_B_1
# 154                      HT1_A_127
# 155  AMQ_A_427,AMQ_B_428,AMQ_C_429
#
# [156 rows x 6 columns]

# %% [markdown]
# #### 6.7 CSARset2 dataset

# %%
CSARset2_ligand_info_results = parallelize_dataframe(CSARset2_df, extract_ligand_info_bulk, 10)

# %%
CSARset2_ligand_info_results = pd.concat(CSARset2_ligand_info_results)

# %%
CSARset2_df["Total_Lig_info"] = CSARset2_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
CSARset2_df = CSARset2_df.dropna(axis = 0).reset_index(drop=True)
CSARset2_df
# Out:
#       PDB Lig_code Labels                                   OE_stereo_SMILES  \
# 0    1a8i      GLS   5.52  C([C@@H]1[C@H]([C@@H]([C@H]([C@]2(O1)C(=O)NC(=...
# 1    1a99      PUT    5.7                                           C(CCN)CN
# 2    1ax0      A2G   3.13   CC(=O)N[C@@H]1[C@H]([C@H]([C@H](O[C@@H]1O)CO)O)O
# 3    1b6l      PI4    8.3  CC(C)(C)NC(=O)[C@@H]1CCCC[N@]1C[C@H]([C@@H]2Cc...
# 4    1b6m      PI6    8.4  CC[C@H](C)[C@H]1C(=O)NCCCOc2ccc(cc2)C[C@@H](C(...
# ..    ...      ...    ...                                                ...
# 137  2qrk      AMP   4.26  c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3...
# 138  2nn1      M28   5.82                       c1cc(ccc1CCC(=O)O)S(=O)(=O)N
# 139  2pou      I7A   7.42             c1c(cc(c(c1S(=O)(=O)N)Cl)Cl)S(=O)(=O)N
# 140  3cd0      6HI   7.57  CC(C)n1c(c(nc1C(=O)NCc2ccc(cc2)F)c3ccc(cc3)F)C...
# 141  3cda      8HI   7.58  CC(C)n1c(c(c(c1C(=O)Nc2ccc(cc2)S(=O)(=O)N)c3cc...
#
#                                       RDKit_iso_SMILES  \
# 0    O=C1NC(=O)[C@@]2(N1)O[C@H](CO)[C@@H](O)[C@H](O...
# 1                                               NCCCCN
# 2    CC(=O)N[C@@H]1[C@@H](O)[C@@H](O)[C@@H](CO)O[C@...
# 3    CC(C)(C)NC(=O)[C@@H]1CCCCN1C[C@@H](O)[C@@H]1CC...
# 4    CC[C@H](C)[C@@H]1NC(=O)[C@@H](NC[C@@H](O)[C@H]...
# ..                                                 ...
# 137  NC1=C2N=CN([C@@H]3O[C@H](COP(=O)(O)O)[C@@H](O)...
# 138                    NS(=O)(=O)C1=CC=C(CCC(=O)O)C=C1
# 139          NS(=O)(=O)C1=CC(S(N)(=O)=O)=C(Cl)C(Cl)=C1
# 140  CC(C)N1C(C(=O)NCC2=CC=C(F)C=C2)=NC(C2=CC=C(F)C...
# 141  CC(C)N1C(CC[C@@H](O)C[C@@H](O)CC(=O)O)=C(C2=CC...
#
#                               Total_Lig_info
# 0                                  GLS_A_998
# 1    PUT_A_371,PUT_B_371,PUT_C_371,PUT_D_371
# 2                                  A2G_A_401
# 3                                  PI4_A_201
# 4                                  PI6_B_201
# ..                                       ...
# 137                                AMP_A_500
# 138                      M28_A_311,M28_B_312
# 139                               I7A_A_1000
# 140          6HI_B_1,6HI_B_2,6HI_C_4,6HI_D_3
# 141          8HI_A_2,8HI_B_1,8HI_C_4,8HI_D_3
#
# [142 rows x 6 columns]

# %% [markdown]
# #### 6.8 Astex dataset

# %%
Astex_ligand_info_results = parallelize_dataframe(Astex_df, extract_ligand_info_bulk, 10)

# %%
Astex_ligand_info_results = pd.concat(Astex_ligand_info_results)

# %%
Astex_df["Total_Lig_info"] = Astex_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
Astex_df = Astex_df.dropna(axis = 0).reset_index(drop=True)
Astex_df
# Out:
#      PDB Lig_code  Labels                                   OE_stereo_SMILES  \
# 0   1gm8      SOX    4.80  CC1([C@@H](N2[C@H]([S@H]1O)[C@@H](C2=O)NC(=O)C...
# 1   1gpk      HUP    5.37   C/C=C/1\[C@@H]2CC3=C([C@]1(CC(=C2)C)N)C=CC(=O)N3
# 2   1hnn      SKF    6.24                         c1cc2c(cc1S(=O)(=O)N)CNCC2
# 3   1hp0      AD3    6.70  c1cnc(c2c1n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3)C...
# 4   1hq2      PH2    6.77                       C1C(=NC2=C(N1)N=C(NC2=O)N)CO
# ..   ...      ...     ...                                                ...
# 70  1ywr      LI9    7.49  C[C@@H](c1ccccc1)Nc2nccc(n2)C3=C(C(=O)N(N3C)C4...
# 71  1z95      198    7.12  C[C@](CS(=O)(=O)c1ccc(cc1)F)(C(=O)Nc2ccc(c(c2)...
# 72  2bm2      PM2    7.82  c1ccc(cc1)CCc2cc(cnc2)C(=O)N3CCC(CC3)c4cccc(c4)CN
# 73  2br1      PFP    5.14        COc1ccc(cc1)c2c3c(ncnc3oc2c4ccc(cc4)OC)NCCO
# 74  2bsm      BSM    5.82  CCNC(=O)c1c(c([nH]n1)c2cc(c(cc2O)O)Cl)c3ccc(cc...
#
#                                      RDKit_iso_SMILES Measure   Potency Unit  \
# 0   CC1(C)[C@H](C(=O)O)N2C(=O)[C@@H](NC(=O)CC3=CC=...      Km    16.000   uM
# 1      C/C=C1\[C@H]2C=C(C)C[C@]1(N)C1=C(C2)NC(=O)C=C1      Ki     4.300   uM
# 2                       NS(=O)(=O)C1=CC2=C(C=C1)CCNC2      Ki     0.580   uM
# 3   NC1=NC=CC2=C1N=CN2[C@@H]1O[C@H](CO)[C@@H](O)[C...      Ki     0.200   uM
# 4                        NC1=NC2=C(N=C(CO)CN2)C(=O)N1      Kd     0.170   uM
# ..                                                ...     ...       ...  ...
# 70  C[C@H](NC1=NC=CC(C2=C(C3=CC=C(F)C=C3)C(=O)N(C3...    IC50    32.000   nM
# 71  C[C@](O)(CS(=O)(=O)C1=CC=C(F)C=C1)C(=O)NC1=CC=...      Ki     0.076   uM
# 72  NCC1=CC(C2CCN(C(=O)C3=CN=CC(CCC4=CC=CC=C4)=C3)...      Ki     0.015   uM
# 73  COC1=CC=C(C2=C(C3=CC=C(OC)C=C3)C3=C(NCCO)N=CN=...      Ki  7200.000   nM
# 74  CCNC(=O)C1=NNC(C2=CC(Cl)=C(O)C=C2O)=C1C1=CC=C(...    IC50  1500.000   nM
#
#                                  Total_Lig_info
# 0                                    SOX_B_1559
# 1                                    HUP_A_1540
# 2                         SKF_A_3001,SKF_B_3002
# 3                         AD3_A_1315,AD3_B_1316
# 4                                     PH2_A_181
# ..                                          ...
# 70                                    LI9_A_361
# 71                                    198_A_501
# 72  PM2_A_3211,PM2_B_3211,PM2_C_3211,PM2_D_3211
# 73                                   PFP_A_1277
# 74                                   BSM_A_1224
#
# [75 rows x 9 columns]

# %% [markdown]
# #### 6.9 COACH420 dataset

# %%
COACH420_ligand_info_results = parallelize_dataframe(COACH420_df, extract_ligand_info_bulk, 10)

# %%
COACH420_ligand_info_results = pd.concat(COACH420_ligand_info_results)

# %%
COACH420_df["Total_Lig_info"] = COACH420_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
COACH420_df = COACH420_df.dropna(axis = 0).reset_index(drop=True)
COACH420_df
# Out:
#       PDB Lig_code COACH420_chain  \
# 0    1a26      CNA              A
# 1    1a2k      GDP              C
# 2    1a4k      FRA              H
# 3    1a7x      FKA              A
# 4    1afk      PAP              A
# ..    ...      ...            ...
# 353  7dfr      FOL              A
# 354  7dfr      NAP              A
# 355  7est      0Z2              E
# 356  830c      RS1              A
# 357  966c      RS2              A
#
#                                       OE_stereo_SMILES  \
# 0    c1cc(c[n+](c1)[C@@H]2C[C@@H]([C@H]([C@H]2O)O)C...
# 1    c1nc2c(n1[C@H]3[C@@H]([C@@H]([C@H](O3)CO[P@](=...
# 2    CC(=O)Nc1ccc(cc1)N2C(=O)[C@@H]3C4CCC([C@@H]3C2...
# 3    C[C@@H]1C[C@@H]([C@@H]2[C@H](C[C@H]([C@@](O2)(...
# 4    c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3...
# ..                                                 ...
# 353  c1cc(ccc1C(=O)N[C@@H](CCC(=O)O)C(=O)O)NCc2cnc3...
# 354  c1cc(c[n+](c1)[C@H]2[C@@H]([C@@H]([C@H](O2)CO[...
# 355  CC(C)C[C@@H](C(=O)N[C@@H](C)C(=O)Nc1ccc(cc1)C(...
# 356  c1cc(ccc1Oc2ccc(cc2)Cl)S(=O)(=O)CC3(CCOCC3)C(=...
# 357   c1ccc(cc1)Oc2ccc(cc2)S(=O)(=O)C3(CCOCC3)CC(=O)NO
#
#                                       RDKit_iso_SMILES  \
# 0    NC(=O)C1=C[N+]([C@@H]2C[C@H](COP(=O)(O)OP(=O)(...
# 1    NC1=NC2=C(N=CN2[C@@H]2O[C@H](CO[P@](=O)(O)OP(=...
# 2    CC(=O)NC1=CC=C(N2C(=O)[C@@H]3C4CCC(NC(=O)OCC(=...
# 3    CO[C@H]1C[C@@H](C)C/C(C)=C/[C@@H](CCOC(=O)NCC2...
# 4    NC1=C2N=CN([C@@H]3O[C@H](CO[P@@](=O)(O)OP(=O)(...
# ..                                                 ...
# 353  NC1=NC(=O)C2=NC(CNC3=CC=C(C(=O)N[C@@H](CCC(=O)...
# 354  NC(=O)C1=C[N+]([C@@H]2O[C@H](CO[P@@](=O)([O-])...
# 355  CC(C)C[C@H](NC(=O)C(F)(F)F)C(=O)N[C@@H](C)C(=O...
# 356  O=C(NO)C1(CS(=O)(=O)C2=CC=C(OC3=CC=C(Cl)C=C3)C...
# 357  O=C(CC1(S(=O)(=O)C2=CC=C(OC3=CC=CC=C3)C=C2)CCO...
#
#                     Total_Lig_info
# 0                        CNA_A_200
# 1    GDP_C_220,GDP_D_220,GDP_E_220
# 2            FRA_H_3083,FRA_B_3083
# 3                        FKA_B_201
# 4              PAP_A_125,PAP_B_125
# ..                             ...
# 353                      FOL_A_161
# 354                      NAP_A_164
# 355                        0Z2_E_1
# 356                RS1_A_1,RS1_B_1
# 357                        RS2_A_1
#
# [358 rows x 6 columns]

# %% [markdown]
# #### 6.10 HOLO4K dataset

# %%
HOLO4K_ligand_info_results = parallelize_dataframe(HOLO4K_df, extract_ligand_info_bulk, 10)

# %%
HOLO4K_ligand_info_results = pd.concat(HOLO4K_ligand_info_results)

# %%
HOLO4K_df["Total_Lig_info"] = HOLO4K_ligand_info_results.map(lambda a: a if a is not None else None)

# %%
HOLO4K_df = HOLO4K_df.dropna(axis = 0).reset_index(drop=True)
HOLO4K_df
# Out:
#        PDB Lig_code                                   OE_stereo_SMILES  \
# 0     121p      GCP  c1nc2c(n1[C@H]3[C@@H]([C@@H]([C@H](O3)CO[P@](=...
# 1     12as      AMP  c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3...
# 2     13pk      3PG                        C([C@H](C(=O)O)O)OP(=O)(O)O
# 3     13pk      ADP  c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3...
# 4     16pk      BIS  c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3...
# ...    ...      ...                                                ...
# 4214  9gss      GTX  CCCCCCSC[C@@H](C(=O)NCC(=O)O)NC(=O)CC[C@@H](C(...
# 4215  9ldb      NAD  c1cc(c[n+](c1)[C@H]2[C@@H]([C@@H]([C@H](O2)CO[...
# 4216  9ldb      OXM                                     C(=O)(C(=O)O)N
# 4217  9ldt      NAD  c1cc(c[n+](c1)[C@H]2[C@@H]([C@@H]([C@H](O2)CO[...
# 4218  9ldt      OXM                                     C(=O)(C(=O)O)N
#
#                                        RDKit_iso_SMILES  \
# 0     NC1=NC2=C(N=CN2[C@@H]2O[C@H](CO[P@](=O)(O)O[P@...
# 1     NC1=C2N=CN([C@@H]3O[C@H](COP(=O)(O)O)[C@@H](O)...
# 2                             O=C(O)[C@H](O)COP(=O)(O)O
# 3     NC1=C2N=CN([C@@H]3O[C@H](CO[P@](=O)(O)OP(=O)(O...
# 4     NC1=C2N=CN([C@@H]3O[C@H](CO[P@@](=O)(O)O[P@](=...
# ...                                                 ...
# 4214  CCCCCCSC[C@H](NC(=O)CC[C@H]([NH3+])C(=O)O)C(=O...
# 4215  NC(=O)C1=C[N+]([C@@H]2O[C@H](CO[P@@](=O)([O-])...
# 4216                                       NC(=O)C(=O)O
# 4217  NC(=O)C1=C[N+]([C@@H]2O[C@H](CO[P@@](=O)([O-])...
# 4218                                       NC(=O)C(=O)O
#
#                                Total_Lig_info
# 0                                   GCP_A_167
# 1                         AMP_A_332,AMP_B_332
# 2                         3PG_A_423,3PG_B_423
# 3     ADP_A_421,ADP_B_421,ADP_C_421,ADP_D_421
# 4                                   BIS_A_499
# ...                                       ...
# 4214                      GTX_A_211,GTX_B_210
# 4215                      NAD_A_401,NAD_B_401
# 4216                                OXM_B_402
# 4217                      NAD_A_401,NAD_B_401
# 4218                      OXM_A_402,OXM_B_402
#
# [4219 rows x 5 columns]

# %% [markdown]
# ### 7. Save data

# %%
PDBbind_df.to_csv("./preprocessed_data/step2_PDBbind_data.tsv", sep = "\t", index = False)
CASF2016_df.to_csv("./preprocessed_data/step2_CASF2016_data.tsv", sep = "\t", index = False)
CASF2013_df.to_csv("./preprocessed_data/step2_CASF2013_data.tsv", sep = "\t", index = False)
CSAR2014_df.to_csv("./preprocessed_data/step2_CSAR2014_data.tsv", sep = "\t", index = False)
CSAR2012_df.to_csv("./preprocessed_data/step2_CSAR2012_data.tsv", sep = "\t", index = False)
CSARset1_df.to_csv("./preprocessed_data/step2_CSARset1_data.tsv", sep = "\t", index = False)
CSARset2_df.to_csv("./preprocessed_data/step2_CSARset2_data.tsv", sep = "\t", index = False)
Astex_df.to_csv("./preprocessed_data/step2_Astex_data.tsv", sep = "\t", index = False)
COACH420_df.to_csv("./preprocessed_data/step2_COACH420_data.tsv", sep = "\t", index = False)
HOLO4K_df.to_csv("./preprocessed_data/step2_HOLO4K_data.tsv", sep = "\t", index = False)
